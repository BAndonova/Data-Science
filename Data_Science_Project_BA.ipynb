# %% [markdown]
# <div style="text-align: center"><H1><font color=darkgreen> Happiness Index - Analysis </font></H1></div>
# <div style="text-align: center"><H4><font color=black> Bilyana Andonova </font></H4></div>
# <div style="text-align: center"><H4><font color=black> Credit and Collection Specialist at Kofax Schweiz AG</font></H4></div>
# <div style="text-align: center"><H3><font color=darkgreen> The General Question in the Analysis is: </font></H3></div>
# <div style="text-align: center"><H3><font color=orange> Analysis of the main factors influencing the countries' happiness index and does money "buy" happiness? </font></H3></div>

# %% [markdown]
# <div style="text-align: left"><H4><font color=darkgreen>Guidlines</font></H4></div>
# <div style="text-align: justify">To find out the answer of the general question, the project will be structured using the OSEMN methodology, but logically separated of 3 sections (the EMN would be combined in one section).</div>
# <div style="text-align: justify">In order to make a complete analysis all the data is taken in consieration and explored. Everything below is done to fulfil the main purpose - find out if money makes the humans happy and is inginfluencing the happiness index.</div>

# %% [markdown]
# <div style="text-align: justify">**Note that only the files that are coming with this jupyter notebook should be used and should be extracted as they are and not be tampered with, since this may lead to internal errors and/or misinterpretation of data.</div>

# %% [markdown]
# <div style="text-align: left"><H4><font color=darkgreen>Introduction</font></H4></div>
# <div style="text-align: justify">The first dataset contains the information for the world happiness index.
# The joy scores and rankings utilize information from the Gallup World Survey.
# The scores are based on answers to the most life evaluation address inquired within the survey.
# This address, known as the Cantril step, asks respondents to think of a step with the most excellent
# conceivable life for them being a 10 and the most exceedingly bad conceivable life being a and to rate their
# claim current lives on that scale. The scores are from broadly agent tests for the a long time 2013-2019 and
# utilize the Gallup weights to create the gauges agent. in the current project only the last survey results from 2019 are taken inot consideration for the analysis. The columns taking after the bliss score assess the
# degree to which each of six variables – financial generation, social back, life anticipation, flexibility,
# nonattendance of debasement, and liberality – contribute to making life assessments higher in each nation
# than they are in Dystopia, a theoretical nation that has values rise to to the world’s least national
# midpoints for each of the six variables.</div>
# <div style="text-align: justify">The Happiness Score is a national average of the responses to the main life evaluation question asked in the Gallup World Poll (GWP), which uses the Cantril Ladder.</div>
#
# <div style="text-align: justify">The Happiness Score is explained by the following factors:</div>
# <div style="text-align: justify">- GDP per capita</div>
# <div style="text-align: justify">- Healthy Life Expectancy</div>
# <div style="text-align: justify">- Social support</div>
# <div style="text-align: justify">- Freedom to make life choices</div>
# <div style="text-align: justify">- Generosity</div>
# <div style="text-align: justify">- Corruption Perception</div>

# %% [markdown]
# <div style="text-align: justify">The remaining datasets represents the The world by income. The World Bank classifies economies for analytical purposes into four income groups: low, lower-middle, upper-middle, and high income. For this purpose it uses gross national income (GNI) per capita data in U.S. dollars, converted from local currency using the World Bank Atlas method, which is applied to smooth exchange rate fluctuations.</div>
# <div style="text-align: justify">Estimates of GNI are obtained from economists in World Bank country units who rely primarily on official data published by the countries; the size of the population is estimated by World Bank demographers from a variety of sources, including the UN’s biennial World Population Prospects.</div>
# <div style="text-align: justify">The data contains information about the current classification by income and historical classification by income in xls format and the Adjusted net national income per capita (current US$) World Bank staff estimates based on sources and methods in World Bank's "The Changing Wealth of Nations: Measuring Sustainable Development in the New Millennium" ( 2011 ).</div>

# %% [markdown]
# <div style="text-align: left"><H4><font color=darkgreen>Parameters of the analysis:</font></H4></div>
# <div style="text-align: justify">1. Timespan - the data for 2019 dynamically defined, based on the data density.</div>
# <div style="text-align: justify">2. Additional data for gross national income per capita (current US$)- data for 2019.</div>
# <div style="text-align: justify">3. Geographical - all countries in the initial datasets dynamically defined, based on their calculated
# happiness index and 5 main KPIs.</div>
# <div style="text-align: justify">4. Attributes - Variety of features dynamically defined, based on the strongest correlation with the happiness index. </div>

# %% [markdown]
# <div style="text-align: left"><H4><font color=darkgreen>The data souces are acquired from: </font></H4></div>
# <div style="text-align: justify"> - World Bank Group (https://data.worldbank.org/) and </div>
# <div style="text-align: justify"> - Kaggle (https://www.kaggle.com/).</div>

# %%
# %matplotlib inline

# %% [markdown]
# <div style="text-align: left"><H3><font color=darkgreen>I. Obtain</font></H3></div>
#
# <div style="text-align: justify">Obtaining the information from the prepared files.</div>

# %%
# Find out your current working directory
print(os.getcwd())
# Out:
# C:\Users\bibsa\Desktop\Data_Science_Exam\data

# %%
# Display all of the files found in your current working directory
print(os.listdir(os.getcwd()))
# Out:
# ['.ipynb_checkpoints', 'Adjusted_net_national_income_per_capita.csv', 'correlations.png', 'Current_classification_by_income.xlsx', 'datasets_748584_1294786_2015.csv', 'datasets_748584_1294786_2016.csv', 'datasets_748584_1294786_2017.csv', 'datasets_748584_1294786_2018.csv', 'datasets_748584_1294786_2019.csv', 'datasets_748584_1294786_2020.csv', 'Exam.ipynb', 'GNIPC-Gross national income per capita 2019-Atlas method and PPP.xlsx', 'GNIPC-Gross national income per capita 2019-Atlas method.xlsx', 'GNIPC-Gross national income per capita 2019-PPP.xlsx', 'Metadata_Country_API_NY.ADJ.NNTY.PC.CD_DS2_en_csv_v2_1222096.csv', 'Metadata_Indicator_API_NY.ADJ.NNTY.PC.CD_DS2_en_csv_v2_1222096.csv', 'Untitled.ipynb']

# %%
#load the file with the happiness data for 2019 using relative path
happiness_2019 = pd.read_csv("datasets_748584_1294786_2019.csv")
happiness_2019
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# ..            ...                       ...    ...             ...
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.587                    0.986                         0.596
# ...

# %%
#explore the data for 2019
happiness_2019.shape
# Out:
# (156, 9)

# %%
#checing the types of the variables
happiness_2019.dtypes
# Out:
# Overall rank                      int64
# Country or region                object
# Score                           float64
# GDP per capita                  float64
# Social support                  float64
# Healthy life expectancy         float64
# Freedom to make life choices    float64
# Generosity                      float64
# Perceptions of corruption       float64
# dtype: object

# %%
#load the file with the Gross national income per capita (current US$) using relative path
gross_national_income_per_capita = pd.read_excel("GNIPC-Gross national income per capita 2019-Atlas method.xlsx")
gross_national_income_per_capita
# Out:
#     Country Abbreviatin  Ranking                   Economy  \
# 0                   CHE      1.0               Switzerland
# 1                   NOR      2.0                    Norway
# 2                   MAC      3.0          Macao SAR, China
# 3                   IMN      4.0               Isle of Man
# 4                   LUX      5.0                Luxembourg
# ..                  ...      ...                       ...
# 212                 SSD      NaN               South Sudan
# 213                 MAF      NaN  St. Martin (French part)
# 214                 SYR      NaN      Syrian Arab Republic
# 215                 VEN      NaN             Venezuela, RB
# 216                 VIR      NaN     Virgin Islands (U.S.)
#
#      Gross National Income per Capita(dollars)
# 0                                        85500
# 1                                        82500
# 2                                        78640
# 3                                        75340
# ...

# %%
#load the file with the Gross national income per capita based on Purchase Power Parity (current US$) using relative path
gross_national_income_per_capita_PPP = pd.read_excel("GNIPC-Gross national income per capita 2019-PPP.xlsx")
gross_national_income_per_capita_PPP
# Out:
#      Ranking                   Economy  \
# 0        1.0          Macao SAR, China
# 1        2.0                     Qatar
# 2        3.0                 Singapore
# 3        4.0                Luxembourg
# 4        5.0               Switzerland
# ..       ...                       ...
# 212      NaN  St. Martin (French part)
# 213      NaN      Syrian Arab Republic
# 214      NaN             Venezuela, RB
# 215      NaN     Virgin Islands (U.S.)
# 216      NaN               Yemen, Rep.
#
#      Purchasing Power Parity 2019 (dollars) Country Abbreviation
# 0                                    123290                  MAC
# 1                                     94170                  QAT
# 2                                     92020                  SGP
# 3                                     77570                  LUX
# 4                                     72390                  CHE
# ..                                      ...                  ...
# ...

# %%
#checking the types of the variables per column / feature
gross_national_income_per_capita.dtypes
# Out:
# Country Abbreviatin                           object
# Ranking                                      float64
# Economy                                       object
# Gross National Income per Capita(dollars)      int64
# dtype: object

# %%
#checking the types of the variables per column / feature
gross_national_income_per_capita_PPP.dtypes
# Out:
# Ranking                                   float64
# Economy                                    object
# Purchasing Power Parity 2019 (dollars)      int64
# Country Abbreviation                       object
# dtype: object

# %%
#explore the data for GNIPC (current US$)
gross_national_income_per_capita.shape
# Out:
# (217, 4)

# %%
#load the file with the Current Clasification by Income using relative path
country_classification = pd.read_excel("Current_classification_by_income.xlsx")
country_classification
# Out:
#        x  x.1                Economy Code    X                      Region  \
# 0      x    x                      x    x    x                           x
# 1      1  NaN            Afghanistan  AFG  NaN                  South Asia
# 2      2  NaN                Albania  ALB  NaN       Europe & Central Asia
# 3      3  NaN                Algeria  DZA  NaN  Middle East & North Africa
# 4      4  NaN         American Samoa  ASM  NaN         East Asia & Pacific
# ..   ...  ...                    ...  ...  ...                         ...
# 214  214  NaN  Virgin Islands (U.S.)  VIR  NaN   Latin America & Caribbean
# 215  215  NaN     West Bank and Gaza  PSE  NaN  Middle East & North Africa
# 216  216  NaN            Yemen, Rep.  YEM  NaN  Middle East & North Africa
# 217  217  NaN                 Zambia  ZMB  NaN          Sub-Saharan Africa
# 218  218  NaN               Zimbabwe  ZWE  NaN          Sub-Saharan Africa
#
#             Income group Lending category Other
# ...

# %%
#explore the data for Current Clasification by Income - 219 rows and 9 columns are available
country_classification.shape
# Out:
# (219, 9)

# %%
#checking the type of the variables in the available columns
country_classification.dtypes
# Out:
# x                   object
# x.1                 object
# Economy             object
# Code                object
# X                   object
# Region              object
# Income group        object
# Lending category    object
# Other               object
# dtype: object

# %% [markdown]
# <div style="text-align: left"><H3><font color=darkgreen>II Scrub</font></H3></div>
# <div style="text-align: justify">After obtaining data, the next step is to make the data readable and ready for analysis.</div>

# %% [markdown]
# <div style="text-align: justify">As per the below checks, it appears that in the happiness dataset all the cells (values) have the data in the proper format for the analysis. </div>

# %%
#counting the non NA cells. 
happiness_2019.count()
# Out:
# Overall rank                    156
# Country or region               156
# Score                           156
# GDP per capita                  156
# Social support                  156
# Healthy life expectancy         156
# Freedom to make life choices    156
# Generosity                      156
# Perceptions of corruption       156
# dtype: int64

# %%
# Reviewing the information about the dataset
happiness_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Overall rank                  156 non-null    int64
#  1   Country or region             156 non-null    object
#  2   Score                         156 non-null    float64
#  3   GDP per capita                156 non-null    float64
#  4   Social support                156 non-null    float64
#  5   Healthy life expectancy       156 non-null    float64
#  6   Freedom to make life choices  156 non-null    float64
#  7   Generosity                    156 non-null    float64
#  8   Perceptions of corruption     156 non-null    float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 11.1+ KB

# %%
#remove the not necessary columns
happiness_2019.drop('Overall rank', axis=1, inplace=True)
happiness_2019
# Out:
#             Country or region  Score  GDP per capita  Social support  \
# 0                     Finland  7.769           1.340           1.587
# 1                     Denmark  7.600           1.383           1.573
# 2                      Norway  7.554           1.488           1.582
# 3                     Iceland  7.494           1.380           1.624
# 4                 Netherlands  7.488           1.396           1.522
# ..                        ...    ...             ...             ...
# 151                    Rwanda  3.334           0.359           0.711
# 152                  Tanzania  3.231           0.476           0.885
# 153               Afghanistan  3.203           0.350           0.517
# 154  Central African Republic  3.083           0.026           0.000
# 155               South Sudan  2.853           0.306           0.575
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# ...

# %%
#renaming the Happiness score column to 
happiness_2019=happiness_2019.rename(columns = {'Score':'Happiness Index 2019'})
happiness_2019
# Out:
#             Country or region  Happiness Index 2019  GDP per capita  \
# 0                     Finland                 7.769           1.340
# 1                     Denmark                 7.600           1.383
# 2                      Norway                 7.554           1.488
# 3                     Iceland                 7.494           1.380
# 4                 Netherlands                 7.488           1.396
# ..                        ...                   ...             ...
# 151                    Rwanda                 3.334           0.359
# 152                  Tanzania                 3.231           0.476
# 153               Afghanistan                 3.203           0.350
# 154  Central African Republic                 3.083           0.026
# 155               South Sudan                 2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# ...

# %%
#counting the non NA cells.
gross_national_income_per_capita.count()
# Out:
# Country Abbreviatin                          217
# Ranking                                      192
# Economy                                      217
# Gross National Income per Capita(dollars)    217
# dtype: int64

# %%
#checking the informtion about the type of the values since it seems there are some NaN values (0 values) available
gross_national_income_per_capita.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 217 entries, 0 to 216
# Data columns (total 4 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Country Abbreviatin                        217 non-null    object
#  1   Ranking                                    192 non-null    float64
#  2   Economy                                    217 non-null    object
#  3   Gross National Income per Capita(dollars)  217 non-null    int64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 6.9+ KB

# %%
#chacking the information about the dataset
gross_national_income_per_capita_PPP.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 217 entries, 0 to 216
# Data columns (total 4 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Ranking                                 192 non-null    float64
#  1   Economy                                 217 non-null    object
#  2   Purchasing Power Parity 2019 (dollars)  217 non-null    int64
#  3   Country Abbreviation                    217 non-null    object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 6.9+ KB

# %%
#checking how many 0 (NaN) values are available in the dataset. It seems that in the Ranking column we have 25. Good that we do not need that column
gross_national_income_per_capita.isnull().sum()
# Out:
# Country Abbreviatin                           0
# Ranking                                      25
# Economy                                       0
# Gross National Income per Capita(dollars)     0
# dtype: int64

# %%
#checking how many 0 (NaN) values are available in the dataset. It seems that in the Ranking column we have 25. It is good that we do not need that column
gross_national_income_per_capita_PPP.isnull().sum()
# Out:
# Ranking                                   25
# Economy                                    0
# Purchasing Power Parity 2019 (dollars)     0
# Country Abbreviation                       0
# dtype: int64

# %%
# Check where we have 0 n(NaN) values and remove them from GNIPC
gross_national_income_per_capita.columns[gross_national_income_per_capita.isnull().any()].tolist()
# Out:
# ['Ranking']

# %%
gross_national_income_per_capita_fin = gross_national_income_per_capita.fillna(0)

# %%
#remove the not needed columns
gross_national_income_per_capita_fin.drop('Country Abbreviatin', axis=1, inplace=True)

# %%
gross_national_income_per_capita_fin.drop('Ranking', axis=1, inplace=True)

# %%
#checking the updated/ tidy dataset
gross_national_income_per_capita_fin
# Out:
#                       Economy  Gross National Income per Capita(dollars)
# 0                 Switzerland                                      85500
# 1                      Norway                                      82500
# 2            Macao SAR, China                                      78640
# 3                 Isle of Man                                      75340
# 4                  Luxembourg                                      73910
# ..                        ...                                        ...
# 212               South Sudan                                          0
# 213  St. Martin (French part)                                          0
# 214      Syrian Arab Republic                                          0
# 215             Venezuela, RB                                          0
# 216     Virgin Islands (U.S.)                                          0
#
# [217 rows x 2 columns]

# %%
#rename the column "Economy"
gross_national_income_per_capita_fin=gross_national_income_per_capita_fin.rename(columns = {'Economy':'Country or region'})

# %%
# check the result of the change in the column names
gross_national_income_per_capita_fin
# Out:
#             Country or region  Gross National Income per Capita(dollars)
# 0                 Switzerland                                      85500
# 1                      Norway                                      82500
# 2            Macao SAR, China                                      78640
# 3                 Isle of Man                                      75340
# 4                  Luxembourg                                      73910
# ..                        ...                                        ...
# 212               South Sudan                                          0
# 213  St. Martin (French part)                                          0
# 214      Syrian Arab Republic                                          0
# 215             Venezuela, RB                                          0
# 216     Virgin Islands (U.S.)                                          0
#
# [217 rows x 2 columns]

# %%
# Similar to the above actions - Replace the NaN/ zero values with 0
gross_national_income_per_capita_fin_PPP = gross_national_income_per_capita_PPP.fillna(0)
gross_national_income_per_capita_fin_PPP
# Out:
#      Ranking                   Economy  \
# 0        1.0          Macao SAR, China
# 1        2.0                     Qatar
# 2        3.0                 Singapore
# 3        4.0                Luxembourg
# 4        5.0               Switzerland
# ..       ...                       ...
# 212      0.0  St. Martin (French part)
# 213      0.0      Syrian Arab Republic
# 214      0.0             Venezuela, RB
# 215      0.0     Virgin Islands (U.S.)
# 216      0.0               Yemen, Rep.
#
#      Purchasing Power Parity 2019 (dollars) Country Abbreviation
# 0                                    123290                  MAC
# 1                                     94170                  QAT
# 2                                     92020                  SGP
# 3                                     77570                  LUX
# 4                                     72390                  CHE
# ..                                      ...                  ...
# ...

# %%
#remove the not needed columns
gross_national_income_per_capita_fin_PPP.drop('Country Abbreviation', axis=1, inplace=True)

# %%
gross_national_income_per_capita_fin_PPP.drop('Ranking', axis=1, inplace=True)

# %%
# check the result of the changes (just in case)
gross_national_income_per_capita_fin_PPP
# Out:
#                       Economy  Purchasing Power Parity 2019 (dollars)
# 0            Macao SAR, China                                  123290
# 1                       Qatar                                   94170
# 2                   Singapore                                   92020
# 3                  Luxembourg                                   77570
# 4                 Switzerland                                   72390
# ..                        ...                                     ...
# 212  St. Martin (French part)                                       0
# 213      Syrian Arab Republic                                       0
# 214             Venezuela, RB                                       0
# 215     Virgin Islands (U.S.)                                       0
# 216               Yemen, Rep.                                       0
#
# [217 rows x 2 columns]

# %%
#rename the column "Economy"
gross_national_income_per_capita_fin_PPP=gross_national_income_per_capita_fin_PPP.rename(columns = {'Economy':'Country or region'})

# %%
gross_national_income_per_capita_fin_PPP
# Out:
#             Country or region  Purchasing Power Parity 2019 (dollars)
# 0            Macao SAR, China                                  123290
# 1                       Qatar                                   94170
# 2                   Singapore                                   92020
# 3                  Luxembourg                                   77570
# 4                 Switzerland                                   72390
# ..                        ...                                     ...
# 212  St. Martin (French part)                                       0
# 213      Syrian Arab Republic                                       0
# 214             Venezuela, RB                                       0
# 215     Virgin Islands (U.S.)                                       0
# 216               Yemen, Rep.                                       0
#
# [217 rows x 2 columns]

# %%
#check and remove NaN values in country_classification 
country_classification.isnull().sum()
# Out:
# x                     0
# x.1                 218
# Economy               0
# Code                  0
# X                   218
# Region                0
# Income group          0
# Lending category      0
# Other               160
# dtype: int64

# %%
country_classification_nan_removed = country_classification.fillna(0)

# %%
country_classification_nan_removed
# Out:
#        x x.1                Economy Code  X                      Region  \
# 0      x   x                      x    x  x                           x
# 1      1   0            Afghanistan  AFG  0                  South Asia
# 2      2   0                Albania  ALB  0       Europe & Central Asia
# 3      3   0                Algeria  DZA  0  Middle East & North Africa
# 4      4   0         American Samoa  ASM  0         East Asia & Pacific
# ..   ...  ..                    ...  ... ..                         ...
# 214  214   0  Virgin Islands (U.S.)  VIR  0   Latin America & Caribbean
# 215  215   0     West Bank and Gaza  PSE  0  Middle East & North Africa
# 216  216   0            Yemen, Rep.  YEM  0  Middle East & North Africa
# 217  217   0                 Zambia  ZMB  0          Sub-Saharan Africa
# 218  218   0               Zimbabwe  ZWE  0          Sub-Saharan Africa
#
#             Income group Lending category Other
# 0                      x                x     x
# ...

# %%
#checking the column names in the format of list (better visibility of their index number). After that removing the not needed columns based on their indexes
list(country_classification_nan_removed.columns.values)
# Out:
# ['x',
#  'x.1',
#  'Economy',
#  'Code',
#  'X',
#  'Region',
#  'Income group',
#  'Lending category',
#  'Other']

# %%
country_classification_fin = country_classification_nan_removed.drop(country_classification_nan_removed.columns[[0,1,3,4,7, 8]], axis=1)

# %%
country_classification_fin
# Out:
#                    Economy                      Region         Income group
# 0                        x                           x                    x
# 1              Afghanistan                  South Asia           Low income
# 2                  Albania       Europe & Central Asia  Upper middle income
# 3                  Algeria  Middle East & North Africa  Lower middle income
# 4           American Samoa         East Asia & Pacific  Upper middle income
# ..                     ...                         ...                  ...
# 214  Virgin Islands (U.S.)   Latin America & Caribbean          High income
# 215     West Bank and Gaza  Middle East & North Africa  Lower middle income
# 216            Yemen, Rep.  Middle East & North Africa           Low income
# 217                 Zambia          Sub-Saharan Africa  Lower middle income
# 218               Zimbabwe          Sub-Saharan Africa  Lower middle income
#
# [219 rows x 3 columns]

# %%
#remove the second line since it is empty
country_classification_fin = country_classification_fin.drop(0)

# %%
country_classification_fin
# Out:
#                    Economy                      Region         Income group
# 1              Afghanistan                  South Asia           Low income
# 2                  Albania       Europe & Central Asia  Upper middle income
# 3                  Algeria  Middle East & North Africa  Lower middle income
# 4           American Samoa         East Asia & Pacific  Upper middle income
# 5                  Andorra       Europe & Central Asia          High income
# ..                     ...                         ...                  ...
# 214  Virgin Islands (U.S.)   Latin America & Caribbean          High income
# 215     West Bank and Gaza  Middle East & North Africa  Lower middle income
# 216            Yemen, Rep.  Middle East & North Africa           Low income
# 217                 Zambia          Sub-Saharan Africa  Lower middle income
# 218               Zimbabwe          Sub-Saharan Africa  Lower middle income
#
# [218 rows x 3 columns]

# %%
# Renaming the column Economy 
country_classification_fin=country_classification_fin.rename(columns = {'Economy':'Country or region'})

# %%
country_classification_fin
# Out:
#          Country or region                      Region         Income group
# 1              Afghanistan                  South Asia           Low income
# 2                  Albania       Europe & Central Asia  Upper middle income
# 3                  Algeria  Middle East & North Africa  Lower middle income
# 4           American Samoa         East Asia & Pacific  Upper middle income
# 5                  Andorra       Europe & Central Asia          High income
# ..                     ...                         ...                  ...
# 214  Virgin Islands (U.S.)   Latin America & Caribbean          High income
# 215     West Bank and Gaza  Middle East & North Africa  Lower middle income
# 216            Yemen, Rep.  Middle East & North Africa           Low income
# 217                 Zambia          Sub-Saharan Africa  Lower middle income
# 218               Zimbabwe          Sub-Saharan Africa  Lower middle income
#
# [218 rows x 3 columns]

# %% [markdown]
# <div style="text-align: justify"> The next steps are related with combining the 4 datasets into one using - Outer Merge. I used it becasue I wanted to see all the available data from the datasets. And the outer merger reurns all the rows from the left dataframe, all the rows from the right dataframe, and matches up rows where possible, with NaNs elsewhere. The data is merged based on the common column 'Country or region'.</div>

# %% [markdown]
# Firstly, we merge the dataset of the happiness index with the dataset containing information about the gross national income per capita

# %%
working_df_gnipc = pd.merge(happiness_2019, gross_national_income_per_capita_fin, how = 'outer', on = ['Country or region'])

# %%
working_df_gnipc
# Out:
#              Country or region  Happiness Index 2019  GDP per capita  \
# 0                      Finland                 7.769           1.340
# 1                      Denmark                 7.600           1.383
# 2                       Norway                 7.554           1.488
# 3                      Iceland                 7.494           1.380
# 4                  Netherlands                 7.488           1.396
# ..                         ...                   ...             ...
# 232  Sint Maarten (Dutch part)                   NaN             NaN
# 233   St. Martin (French part)                   NaN             NaN
# 234       Syrian Arab Republic                   NaN             NaN
# 235              Venezuela, RB                   NaN             NaN
# 236      Virgin Islands (U.S.)                   NaN             NaN
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# ...

# %% [markdown]
# As second step of combining the data is the merging of the preciously combined dataset with the additional data for the purchase power parity. Again based on the common column named "Country or region".

# %%
working_df = pd.merge(working_df_gnipc, gross_national_income_per_capita_fin_PPP, how = 'outer', on = ['Country or region'])

# %%
working_df
# Out:
#              Country or region  Happiness Index 2019  GDP per capita  \
# 0                      Finland                 7.769           1.340
# 1                      Denmark                 7.600           1.383
# 2                       Norway                 7.554           1.488
# 3                      Iceland                 7.494           1.380
# 4                  Netherlands                 7.488           1.396
# ..                         ...                   ...             ...
# 232  Sint Maarten (Dutch part)                   NaN             NaN
# 233   St. Martin (French part)                   NaN             NaN
# 234       Syrian Arab Republic                   NaN             NaN
# 235              Venezuela, RB                   NaN             NaN
# 236      Virgin Islands (U.S.)                   NaN             NaN
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# ...

# %%
# Checking if there are NaN values in the newly formed dataset. As visible below we have 81 rows with NaN value in the column "Happiness Index 2019"
working_df[working_df['Happiness Index 2019'].isnull()]
# Out:
#              Country or region  Happiness Index 2019  GDP per capita  \
# 156           Macao SAR, China                   NaN             NaN
# 157                Isle of Man                   NaN             NaN
# 158       Hong Kong SAR, China                   NaN             NaN
# 159             Cayman Islands                   NaN             NaN
# 160                Korea, Rep.                   NaN             NaN
# ..                         ...                   ...             ...
# 232  Sint Maarten (Dutch part)                   NaN             NaN
# 233   St. Martin (French part)                   NaN             NaN
# 234       Syrian Arab Republic                   NaN             NaN
# 235              Venezuela, RB                   NaN             NaN
# 236      Virgin Islands (U.S.)                   NaN             NaN
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# ...

# %%
#replace NaN values with zero
working_df = working_df.fillna(0)

# %%
working_df
# Out:
#              Country or region  Happiness Index 2019  GDP per capita  \
# 0                      Finland                 7.769           1.340
# 1                      Denmark                 7.600           1.383
# 2                       Norway                 7.554           1.488
# 3                      Iceland                 7.494           1.380
# 4                  Netherlands                 7.488           1.396
# ..                         ...                   ...             ...
# 232  Sint Maarten (Dutch part)                 0.000           0.000
# 233   St. Martin (French part)                 0.000           0.000
# 234       Syrian Arab Republic                 0.000           0.000
# 235              Venezuela, RB                 0.000           0.000
# 236      Virgin Islands (U.S.)                 0.000           0.000
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# ...

# %% [markdown]
# <div style="text-align: justify">After the NaN values are replaced with zeros it will be good to check if there are some duplicated records in the naming of the countries in scope.</div>
# <div style="text-align: justify">Since the data is coming from different sources it seems we also have some countries existing as 2 records with slightly different naming.</div>
# <div style="text-align: justify">And what we need to do in order to finish the data tidying, we should summarize the multiple records under one row, i.e. having only one observation. Otherwize the data would not be acurate in the further analysis...</div>
# <div style="text-align: justify">The  main starting point here are the zero values observations in the Happiness Index 2019 columns. </div>
# <div style="text-align: justify">After that we change the name of the country making it common and summarize with aggregation the values of all the numeric coumns at one line. </div>

# %%
#select the zero values observations as per "Happiness Index 2019"
select_zero_values_one = working_df.loc[(working_df['Happiness Index 2019'] == 0)]
select_zero_values_one.head()
# Out:
#         Country or region  Happiness Index 2019  GDP per capita  \
# 156      Macao SAR, China                   0.0             0.0
# 157           Isle of Man                   0.0             0.0
# 158  Hong Kong SAR, China                   0.0             0.0
# 159        Cayman Islands                   0.0             0.0
# 160           Korea, Rep.                   0.0             0.0
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 156             0.0                      0.0                           0.0
# 157             0.0                      0.0                           0.0
# 158             0.0                      0.0                           0.0
# 159             0.0                      0.0                           0.0
# 160             0.0                      0.0                           0.0
#
#      Generosity  Perceptions of corruption  \
# 156         0.0                        0.0
# ...

# %%
#creating list from all the Countries having zero value in the happiness index column
zero_values_list_one = select_zero_values_one["Country or region"].tolist()
zero_values_list_one
# Out:
# ['Macao SAR, China',
#  'Isle of Man',
#  'Hong Kong SAR, China',
#  'Cayman Islands',
#  'Korea, Rep.',
#  'Brunei Darussalam',
#  'Bahamas, The',
#  'Aruba',
#  'Turks and Caicos Islands',
#  'Puerto Rico',
#  'Curaçao',
#  'Slovak Republic',
#  'St. Kitts and Nevis',
#  'Barbados',
#  'Palau',
#  'Trinidad and Tobago',
#  'Seychelles',
#  'Antigua and Barbuda',
#  'Oman',
#  'Nauru',
#  'Russian Federation',
#  'St. Lucia',
#  'Grenada',
#  'Maldives',
#  'Dominica',
#  'St. Vincent and the Grenadines',
#  'Equatorial Guinea',
#  'Fiji',
#  'Tuvalu',
#  'Suriname',
#  'Iran, Islamic Rep.',
#  'Guyana',
#  'Marshall Islands',
#  'Belize',
#  'Tonga',
#  'Samoa',
#  'West Bank and Gaza',
#  'Cabo Verde',
#  'Eswatini',
#  'Djibouti',
#  'Micronesia, Fed. Sts.',
#  'Kiribati',
#  'Vanuatu',
#  'Angola',
#  'Papua New Guinea',
#  'Egypt, Arab Rep.',
#  'Lao PDR',
#  "Côte d'Ivoire",
#  'Solomon Islands',
#  'São Tomé and Principe',
#  'Timor-Leste',
#  'Congo, Rep.',
# ...

# %%
#check if duplicated values for Macedonia
working_df[working_df['Country or region'].str.contains("Macedonia")]
# Out:
#    Country or region  Happiness Index 2019  GDP per capita  Social support  \
# 83   North Macedonia                 5.274           0.983           1.294
#
#     Healthy life expectancy  Freedom to make life choices  Generosity  \
# 83                    0.838                         0.345       0.185
#
#     Perceptions of corruption  Gross National Income per Capita(dollars)  \
# 83                      0.034                                     5910.0
#
#     Purchasing Power Parity 2019 (dollars)
# 83                                 17110.0

# %%
#check if duplicated values for Hong Kong
working_df[working_df['Country or region'].str.contains("Hong Kong")]
# Out:
#         Country or region  Happiness Index 2019  GDP per capita  \
# 75              Hong Kong                  5.43           1.438
# 158  Hong Kong SAR, China                  0.00           0.000
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 75            1.277                    1.122                          0.44
# 158           0.000                    0.000                          0.00
#
#      Generosity  Perceptions of corruption  \
# 75        0.258                      0.287
# 158       0.000                      0.000
#
#      Gross National Income per Capita(dollars)  \
# 75                                         0.0
# 158                                    50840.0
#
#      Purchasing Power Parity 2019 (dollars)
# 75                                      0.0
# 158                                 65600.0

# %%
#correct the duplicated lines and delete the not needed one and check if the correction is successful
working_df['Country'] = working_df['Country or region'].replace(['Hong Kong'],'Hong Kong SAR, China')
working_df['Country or region'] = working_df['Country']

# %%
working_df[working_df['Country or region'].str.contains("Hong Kong")]
# Out:
#         Country or region  Happiness Index 2019  GDP per capita  \
# 75   Hong Kong SAR, China                  5.43           1.438
# 158  Hong Kong SAR, China                  0.00           0.000
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 75            1.277                    1.122                          0.44
# 158           0.000                    0.000                          0.00
#
#      Generosity  Perceptions of corruption  \
# 75        0.258                      0.287
# 158       0.000                      0.000
#
#      Gross National Income per Capita(dollars)  \
# 75                                         0.0
# 158                                    50840.0
#
#      Purchasing Power Parity 2019 (dollars)               Country
# 75                                      0.0  Hong Kong SAR, China
# 158                                 65600.0  Hong Kong SAR, China

# %%
aggregation_functions = {'Happiness Index 2019': 'sum',
                         'GDP per capita': 'sum',
                         'Social support': 'sum',
                         'Healthy life expectancy': 'sum',
                         'Freedom to make life choices': 'sum',
                         'Generosity': 'sum',
                         'Perceptions of corruption': 'sum',
                         'Gross National Income per Capita(dollars)': 'sum', 
                         'Purchasing Power Parity 2019 (dollars)': 'sum', 
                         'Country or region': 'first'}
working_df = working_df.groupby(working_df['Country']).aggregate(aggregation_functions)

# %%
#check if duplicated values for Hong Kong
working_df[working_df['Country or region'].str.contains("Hong Kong")]
# Out:
#                       Happiness Index 2019  GDP per capita  Social support  \
# Country
# Hong Kong SAR, China                  5.43           1.438           1.277
#
#                       Healthy life expectancy  Freedom to make life choices  \
# Country
# Hong Kong SAR, China                    1.122                          0.44
#
#                       Generosity  Perceptions of corruption  \
# Country
# Hong Kong SAR, China       0.258                      0.287
#
#                       Gross National Income per Capita(dollars)  \
# Country
# Hong Kong SAR, China                                    50840.0
#
#                       Purchasing Power Parity 2019 (dollars)  \
# Country
# Hong Kong SAR, China                                 65600.0
#
#                          Country or region
# Country
# Hong Kong SAR, China  Hong Kong SAR, China

# %%
#check if duplicated values for Hong Kong
working_df[working_df['Country or region'].str.contains("Cyprus")]
# Out:
#                  Happiness Index 2019  GDP per capita  Social support  \
# Country
# Cyprus                          6.046           1.263           1.223
# Northern Cyprus                 5.718           1.263           1.252
#
#                  Healthy life expectancy  Freedom to make life choices  \
# Country
# Cyprus                             1.042                         0.406
# Northern Cyprus                    1.042                         0.417
#
#                  Generosity  Perceptions of corruption  \
# Country
# Cyprus                0.190                      0.041
# Northern Cyprus       0.191                      0.162
#
#                  Gross National Income per Capita(dollars)  \
# Country
# Cyprus                                             27710.0
# Northern Cyprus                                        0.0
#
#                  Purchasing Power Parity 2019 (dollars) Country or region
# Country
# ...

# %%
#check if duplicated values for Yemen
working_df[working_df['Country or region'].str.contains("Yemen")]
# Out:
#              Happiness Index 2019  GDP per capita  Social support  \
# Country
# Yemen                        3.38           0.287           1.163
# Yemen, Rep.                  0.00           0.000           0.000
#
#              Healthy life expectancy  Freedom to make life choices  \
# Country
# Yemen                          0.463                         0.143
# Yemen, Rep.                    0.000                         0.000
#
#              Generosity  Perceptions of corruption  \
# Country
# Yemen             0.108                      0.077
# Yemen, Rep.       0.000                      0.000
#
#              Gross National Income per Capita(dollars)  \
# Country
# Yemen                                              0.0
# Yemen, Rep.                                      940.0
#
#              Purchasing Power Parity 2019 (dollars) Country or region
# Country
# Yemen                                           0.0             Yemen
# ...

# %%
#correct the duplicated lines and delete the not needed one and check if the correction is successful
working_df['Country'] = working_df['Country or region'].replace(['Yemen'],'Yemen, Rep.')
working_df['Country or region'] = working_df['Country']

# %%
aggregation_functions = {'Happiness Index 2019': 'sum',
                         'GDP per capita': 'sum',
                         'Social support': 'sum',
                         'Healthy life expectancy': 'sum',
                         'Freedom to make life choices': 'sum',
                         'Generosity': 'sum',
                         'Perceptions of corruption': 'sum',
                         'Gross National Income per Capita(dollars)': 'sum', 
                         'Purchasing Power Parity 2019 (dollars)': 'sum', 
                         'Country or region': 'first'}
working_df = working_df.groupby(working_df['Country']).aggregate(aggregation_functions)

# %%
#check if duplicated values for Yemen
working_df[working_df['Country or region'].str.contains("Yemen")]
# Out:
#              Happiness Index 2019  GDP per capita  Social support  \
# Country
# Yemen, Rep.                  3.38           0.287           1.163
#
#              Healthy life expectancy  Freedom to make life choices  \
# Country
# Yemen, Rep.                    0.463                         0.143
#
#              Generosity  Perceptions of corruption  \
# Country
# Yemen, Rep.       0.108                      0.077
#
#              Gross National Income per Capita(dollars)  \
# Country
# Yemen, Rep.                                      940.0
#
#              Purchasing Power Parity 2019 (dollars) Country or region
# Country
# Yemen, Rep.                                     0.0       Yemen, Rep.

# %%
#refreshing the list with selecting the zero values with adding additional conditions for having zeros in the 3 columns:
#'Happiness Index 2019', 'Gross National Income per Capita(dollars)' and 'Purchasing Power Parity 2019 (dollars)'
select_zero_values = working_df.loc[(working_df['Happiness Index 2019'] == 0) & 
                                    (working_df['Gross National Income per Capita(dollars)'] == 0) & 
                                   (working_df['Purchasing Power Parity 2019 (dollars)']==0)]
select_zero_values.head()
# Out:
#                         Happiness Index 2019  GDP per capita  Social support  \
# Country
# American Samoa                           0.0             0.0             0.0
# Andorra                                  0.0             0.0             0.0
# Bermuda                                  0.0             0.0             0.0
# British Virgin Islands                   0.0             0.0             0.0
# Channel Islands                          0.0             0.0             0.0
#
#                         Healthy life expectancy  Freedom to make life choices  \
# Country
# American Samoa                              0.0                           0.0
# Andorra                                     0.0                           0.0
# Bermuda                                     0.0                           0.0
# British Virgin Islands                      0.0                           0.0
# Channel Islands                             0.0                           0.0
#
# ...

# %%
#creating list from the countries names matching the above conditions
zero_values_list = select_zero_values["Country or region"].tolist()
zero_values_list
# Out:
# ['American Samoa',
#  'Andorra',
#  'Bermuda',
#  'British Virgin Islands',
#  'Channel Islands',
#  'Cuba',
#  'Eritrea',
#  'Faroe Islands',
#  'French Polynesia',
#  'Gibraltar',
#  'Greenland',
#  'Guam',
#  "Korea, Dem. People's Rep.",
#  'Liechtenstein',
#  'Monaco',
#  'New Caledonia',
#  'Northern Mariana Islands',
#  'San Marino',
#  'St. Martin (French part)',
#  'Syrian Arab Republic',
#  'Venezuela, RB',
#  'Virgin Islands (U.S.)']

# %%
#check if duplicated values for Samoa - they are 2 different countries
working_df[working_df['Country or region'].str.contains("Samoa")]
# Out:
#                 Happiness Index 2019  GDP per capita  Social support  \
# Country
# American Samoa                   0.0             0.0             0.0
# Samoa                            0.0             0.0             0.0
#
#                 Healthy life expectancy  Freedom to make life choices  \
# Country
# American Samoa                      0.0                           0.0
# Samoa                               0.0                           0.0
#
#                 Generosity  Perceptions of corruption  \
# Country
# American Samoa         0.0                        0.0
# Samoa                  0.0                        0.0
#
#                 Gross National Income per Capita(dollars)  \
# Country
# American Samoa                                        0.0
# Samoa                                              4180.0
#
#                 Purchasing Power Parity 2019 (dollars) Country or region
# Country
# American Samoa                                     0.0    American Samoa
# ...

# %%
#check if duplicated values for Andorra - OK, only 1 time existing in the df
working_df[working_df['Country or region'].str.contains("Andorra")]
# Out:
#          Happiness Index 2019  GDP per capita  Social support  \
# Country
# Andorra                   0.0             0.0             0.0
#
#          Healthy life expectancy  Freedom to make life choices  Generosity  \
# Country
# Andorra                      0.0                           0.0         0.0
#
#          Perceptions of corruption  Gross National Income per Capita(dollars)  \
# Country
# Andorra                        0.0                                        0.0
#
#          Purchasing Power Parity 2019 (dollars) Country or region
# Country
# Andorra                                     0.0           Andorra

# %%
#check if duplicated values for Bermuda - OK, only 1 time existing in the df
working_df[working_df['Country or region'].str.contains("Bermuda")]
# Out:
#          Happiness Index 2019  GDP per capita  Social support  \
# Country
# Bermuda                   0.0             0.0             0.0
#
#          Healthy life expectancy  Freedom to make life choices  Generosity  \
# Country
# Bermuda                      0.0                           0.0         0.0
#
#          Perceptions of corruption  Gross National Income per Capita(dollars)  \
# Country
# Bermuda                        0.0                                        0.0
#
#          Purchasing Power Parity 2019 (dollars) Country or region
# Country
# Bermuda                                     0.0           Bermuda

# %%
#check if duplicated values for British Virgin Islands - OK, only 1 time existing in the df
working_df[working_df['Country or region'].str.contains("Virgin Islands")]
# Out:
#                         Happiness Index 2019  GDP per capita  Social support  \
# Country
# British Virgin Islands                   0.0             0.0             0.0
# Virgin Islands (U.S.)                    0.0             0.0             0.0
#
#                         Healthy life expectancy  Freedom to make life choices  \
# Country
# British Virgin Islands                      0.0                           0.0
# Virgin Islands (U.S.)                       0.0                           0.0
#
#                         Generosity  Perceptions of corruption  \
# Country
# British Virgin Islands         0.0                        0.0
# Virgin Islands (U.S.)          0.0                        0.0
#
#                         Gross National Income per Capita(dollars)  \
# Country
# British Virgin Islands                                        0.0
# Virgin Islands (U.S.)                                         0.0
#
# ...

# %%
#check if duplicated values for Channel Islands - OK, only 1 time existing in the df
working_df[working_df['Country or region'].str.contains("Channel")]
# Out:
#                  Happiness Index 2019  GDP per capita  Social support  \
# Country
# Channel Islands                   0.0             0.0             0.0
#
#                  Healthy life expectancy  Freedom to make life choices  \
# Country
# Channel Islands                      0.0                           0.0
#
#                  Generosity  Perceptions of corruption  \
# Country
# Channel Islands         0.0                        0.0
#
#                  Gross National Income per Capita(dollars)  \
# Country
# Channel Islands                                        0.0
#
#                  Purchasing Power Parity 2019 (dollars) Country or region
# Country
# Channel Islands                                     0.0   Channel Islands

# %%
#check if duplicated values for Cuba - OK, only 1 time existing in the df
working_df[working_df['Country or region'].str.contains("Cuba")]
# Out:
#          Happiness Index 2019  GDP per capita  Social support  \
# Country
# Cuba                      0.0             0.0             0.0
#
#          Healthy life expectancy  Freedom to make life choices  Generosity  \
# Country
# Cuba                         0.0                           0.0         0.0
#
#          Perceptions of corruption  Gross National Income per Capita(dollars)  \
# Country
# Cuba                           0.0                                        0.0
#
#          Purchasing Power Parity 2019 (dollars) Country or region
# Country
# Cuba                                        0.0              Cuba

# %%
#check if duplicated values for Eritrea - OK, only 1 time existing in the df
working_df[working_df['Country or region'].str.contains("Eritrea")]
# Out:
#          Happiness Index 2019  GDP per capita  Social support  \
# Country
# Eritrea                   0.0             0.0             0.0
#
#          Healthy life expectancy  Freedom to make life choices  Generosity  \
# Country
# Eritrea                      0.0                           0.0         0.0
#
#          Perceptions of corruption  Gross National Income per Capita(dollars)  \
# Country
# Eritrea                        0.0                                        0.0
#
#          Purchasing Power Parity 2019 (dollars) Country or region
# Country
# Eritrea                                     0.0           Eritrea

# %%
#check if duplicated values for Faroe - OK, only 1 time existing in the df
working_df[working_df['Country or region'].str.contains("Faroe")]
# Out:
#                Happiness Index 2019  GDP per capita  Social support  \
# Country
# Faroe Islands                   0.0             0.0             0.0
#
#                Healthy life expectancy  Freedom to make life choices  \
# Country
# Faroe Islands                      0.0                           0.0
#
#                Generosity  Perceptions of corruption  \
# Country
# Faroe Islands         0.0                        0.0
#
#                Gross National Income per Capita(dollars)  \
# Country
# Faroe Islands                                        0.0
#
#                Purchasing Power Parity 2019 (dollars) Country or region
# Country
# Faroe Islands                                     0.0     Faroe Islands

# %%
#check if duplicated values for Polynesia - OK, only 1 time existing in the df
working_df[working_df['Country or region'].str.contains("Polynesia")]
# Out:
#                   Happiness Index 2019  GDP per capita  Social support  \
# Country
# French Polynesia                   0.0             0.0             0.0
#
#                   Healthy life expectancy  Freedom to make life choices  \
# Country
# French Polynesia                      0.0                           0.0
#
#                   Generosity  Perceptions of corruption  \
# Country
# French Polynesia         0.0                        0.0
#
#                   Gross National Income per Capita(dollars)  \
# Country
# French Polynesia                                        0.0
#
#                   Purchasing Power Parity 2019 (dollars) Country or region
# Country
# French Polynesia                                     0.0  French Polynesia

# %%
#check if duplicated values for Gibraltar - OK, only 1 time existing in the df
working_df[working_df['Country or region'].str.contains("Gibraltar")]
# Out:
#            Happiness Index 2019  GDP per capita  Social support  \
# Country
# Gibraltar                   0.0             0.0             0.0
#
#            Healthy life expectancy  Freedom to make life choices  Generosity  \
# Country
# Gibraltar                      0.0                           0.0         0.0
#
#            Perceptions of corruption  \
# Country
# Gibraltar                        0.0
#
#            Gross National Income per Capita(dollars)  \
# Country
# Gibraltar                                        0.0
#
#            Purchasing Power Parity 2019 (dollars) Country or region
# Country
# Gibraltar                                     0.0         Gibraltar

# %%
#check if duplicated values for Gibraltar - OK, only 1 time existing in the df
working_df[working_df['Country or region'].str.contains("Greenland")]
# Out:
#            Happiness Index 2019  GDP per capita  Social support  \
# Country
# Greenland                   0.0             0.0             0.0
#
#            Healthy life expectancy  Freedom to make life choices  Generosity  \
# Country
# Greenland                      0.0                           0.0         0.0
#
#            Perceptions of corruption  \
# Country
# Greenland                        0.0
#
#            Gross National Income per Capita(dollars)  \
# Country
# Greenland                                        0.0
#
#            Purchasing Power Parity 2019 (dollars) Country or region
# Country
# Greenland                                     0.0         Greenland

# %%
#check if duplicated values for Guam - OK, only 1 time existing in the df
working_df[working_df['Country or region'].str.contains("Guam")]
# Out:
#          Happiness Index 2019  GDP per capita  Social support  \
# Country
# Guam                      0.0             0.0             0.0
#
#          Healthy life expectancy  Freedom to make life choices  Generosity  \
# Country
# Guam                         0.0                           0.0         0.0
#
#          Perceptions of corruption  Gross National Income per Capita(dollars)  \
# Country
# Guam                           0.0                                        0.0
#
#          Purchasing Power Parity 2019 (dollars) Country or region
# Country
# Guam                                        0.0              Guam

# %%
#check if duplicated values for Korea - South Korea == Korea, Rep. => to be merged
working_df[working_df['Country or region'].str.contains("Korea")]
# Out:
#                            Happiness Index 2019  GDP per capita  \
# Country
# Korea, Dem. People's Rep.                 0.000           0.000
# Korea, Rep.                               0.000           0.000
# South Korea                               5.895           1.301
#
#                            Social support  Healthy life expectancy  \
# Country
# Korea, Dem. People's Rep.           0.000                    0.000
# Korea, Rep.                         0.000                    0.000
# South Korea                         1.219                    1.036
#
#                            Freedom to make life choices  Generosity  \
# Country
# Korea, Dem. People's Rep.                         0.000       0.000
# Korea, Rep.                                       0.000       0.000
# South Korea                                       0.159       0.175
#
#                            Perceptions of corruption  \
# Country
# Korea, Dem. People's Rep.                      0.000
# ...

# %%
working_df['Country'] = working_df['Country or region'].replace(['South Korea'],'Korea, Rep.')
working_df['Country or region'] = working_df['Country']

# %%
aggregation_functions = {'Happiness Index 2019': 'sum',
                         'GDP per capita': 'sum',
                         'Social support': 'sum',
                         'Healthy life expectancy': 'sum',
                         'Freedom to make life choices': 'sum',
                         'Generosity': 'sum',
                         'Perceptions of corruption': 'sum',
                         'Gross National Income per Capita(dollars)': 'sum', 
                         'Purchasing Power Parity 2019 (dollars)': 'sum', 
                         'Country or region': 'first'}
working_df = working_df.groupby(working_df['Country']).aggregate(aggregation_functions)

# %%
working_df[working_df['Country or region'].str.contains("Korea")]
# Out:
#                            Happiness Index 2019  GDP per capita  \
# Country
# Korea, Dem. People's Rep.                 0.000           0.000
# Korea, Rep.                               5.895           1.301
#
#                            Social support  Healthy life expectancy  \
# Country
# Korea, Dem. People's Rep.           0.000                    0.000
# Korea, Rep.                         1.219                    1.036
#
#                            Freedom to make life choices  Generosity  \
# Country
# Korea, Dem. People's Rep.                         0.000       0.000
# Korea, Rep.                                       0.159       0.175
#
#                            Perceptions of corruption  \
# Country
# Korea, Dem. People's Rep.                      0.000
# Korea, Rep.                                    0.056
#
#                            Gross National Income per Capita(dollars)  \
# Country
# Korea, Dem. People's Rep.                                        0.0
# ...

# %%
#check if duplicated values for Liechtenstein - OK, only 1 time in the dataframe
working_df[working_df['Country or region'].str.contains("Liechtenstein")]
# Out:
#                Happiness Index 2019  GDP per capita  Social support  \
# Country
# Liechtenstein                   0.0             0.0             0.0
#
#                Healthy life expectancy  Freedom to make life choices  \
# Country
# Liechtenstein                      0.0                           0.0
#
#                Generosity  Perceptions of corruption  \
# Country
# Liechtenstein         0.0                        0.0
#
#                Gross National Income per Capita(dollars)  \
# Country
# Liechtenstein                                        0.0
#
#                Purchasing Power Parity 2019 (dollars) Country or region
# Country
# Liechtenstein                                     0.0     Liechtenstein

# %%
#check if duplicated values for Monaco - OK, only 1 time in the dataframe
working_df[working_df['Country or region'].str.contains("Monaco")]
# Out:
#          Happiness Index 2019  GDP per capita  Social support  \
# Country
# Monaco                    0.0             0.0             0.0
#
#          Healthy life expectancy  Freedom to make life choices  Generosity  \
# Country
# Monaco                       0.0                           0.0         0.0
#
#          Perceptions of corruption  Gross National Income per Capita(dollars)  \
# Country
# Monaco                         0.0                                        0.0
#
#          Purchasing Power Parity 2019 (dollars) Country or region
# Country
# Monaco                                      0.0            Monaco

# %%
#check if duplicated values for New Caledonia - OK, only 1 time in the dataframe
working_df[working_df['Country or region'].str.contains("Caledonia")]
# Out:
#                Happiness Index 2019  GDP per capita  Social support  \
# Country
# New Caledonia                   0.0             0.0             0.0
#
#                Healthy life expectancy  Freedom to make life choices  \
# Country
# New Caledonia                      0.0                           0.0
#
#                Generosity  Perceptions of corruption  \
# Country
# New Caledonia         0.0                        0.0
#
#                Gross National Income per Capita(dollars)  \
# Country
# New Caledonia                                        0.0
#
#                Purchasing Power Parity 2019 (dollars) Country or region
# Country
# New Caledonia                                     0.0     New Caledonia

# %%
#check if duplicated values for Northern Mariana Island - OK, only 1 time in the dataframe
working_df[working_df['Country or region'].str.contains("Mariana Island")]
# Out:
#                           Happiness Index 2019  GDP per capita  \
# Country
# Northern Mariana Islands                   0.0             0.0
#
#                           Social support  Healthy life expectancy  \
# Country
# Northern Mariana Islands             0.0                      0.0
#
#                           Freedom to make life choices  Generosity  \
# Country
# Northern Mariana Islands                           0.0         0.0
#
#                           Perceptions of corruption  \
# Country
# Northern Mariana Islands                        0.0
#
#                           Gross National Income per Capita(dollars)  \
# Country
# Northern Mariana Islands                                        0.0
#
#                           Purchasing Power Parity 2019 (dollars)  \
# Country
# Northern Mariana Islands                                     0.0
#
#                                  Country or region
# Country
# Northern Mariana Islands  Northern Mariana Islands

# %%
#check if duplicated values for San Marino - OK, only 1 time in the dataframe
working_df[working_df['Country or region'].str.contains("Marino")]
# Out:
#             Happiness Index 2019  GDP per capita  Social support  \
# Country
# San Marino                   0.0             0.0             0.0
#
#             Healthy life expectancy  Freedom to make life choices  Generosity  \
# Country
# San Marino                      0.0                           0.0         0.0
#
#             Perceptions of corruption  \
# Country
# San Marino                        0.0
#
#             Gross National Income per Capita(dollars)  \
# Country
# San Marino                                        0.0
#
#             Purchasing Power Parity 2019 (dollars) Country or region
# Country
# San Marino                                     0.0        San Marino

# %%
#check if duplicated values for St. Martin - OK, only 1 time in the dataframe
working_df[working_df['Country or region'].str.contains("Martin")]
# Out:
#                           Happiness Index 2019  GDP per capita  \
# Country
# St. Martin (French part)                   0.0             0.0
#
#                           Social support  Healthy life expectancy  \
# Country
# St. Martin (French part)             0.0                      0.0
#
#                           Freedom to make life choices  Generosity  \
# Country
# St. Martin (French part)                           0.0         0.0
#
#                           Perceptions of corruption  \
# Country
# St. Martin (French part)                        0.0
#
#                           Gross National Income per Capita(dollars)  \
# Country
# St. Martin (French part)                                        0.0
#
#                           Purchasing Power Parity 2019 (dollars)  \
# Country
# St. Martin (French part)                                     0.0
#
#                                  Country or region
# Country
# St. Martin (French part)  St. Martin (French part)

# %%
#check if duplicated values for Syrian Arab Republic - duplicated => to be merged
working_df[working_df['Country or region'].str.contains("Syria")]
# Out:
#                       Happiness Index 2019  GDP per capita  Social support  \
# Country
# Syria                                3.462           0.619           0.378
# Syrian Arab Republic                 0.000           0.000           0.000
#
#                       Healthy life expectancy  Freedom to make life choices  \
# Country
# Syria                                    0.44                         0.013
# Syrian Arab Republic                     0.00                         0.000
#
#                       Generosity  Perceptions of corruption  \
# Country
# Syria                      0.331                      0.141
# Syrian Arab Republic       0.000                      0.000
#
#                       Gross National Income per Capita(dollars)  \
# Country
# Syria                                                       0.0
# Syrian Arab Republic                                        0.0
#
#                       Purchasing Power Parity 2019 (dollars)  \
# Country
# ...

# %%
working_df['Country'] = working_df['Country or region'].replace(['Syria'],'Syrian Arab Republic')
working_df['Country or region'] = working_df['Country']

# %%
aggregation_functions = {'Happiness Index 2019': 'sum',
                         'GDP per capita': 'sum',
                         'Social support': 'sum',
                         'Healthy life expectancy': 'sum',
                         'Freedom to make life choices': 'sum',
                         'Generosity': 'sum',
                         'Perceptions of corruption': 'sum',
                         'Gross National Income per Capita(dollars)': 'sum', 
                         'Purchasing Power Parity 2019 (dollars)': 'sum', 
                         'Country or region': 'first'}
working_df = working_df.groupby(working_df['Country']).aggregate(aggregation_functions)

# %%
working_df[working_df['Country or region'].str.contains("Syria")]
# Out:
#                       Happiness Index 2019  GDP per capita  Social support  \
# Country
# Syrian Arab Republic                 3.462           0.619           0.378
#
#                       Healthy life expectancy  Freedom to make life choices  \
# Country
# Syrian Arab Republic                     0.44                         0.013
#
#                       Generosity  Perceptions of corruption  \
# Country
# Syrian Arab Republic       0.331                      0.141
#
#                       Gross National Income per Capita(dollars)  \
# Country
# Syrian Arab Republic                                        0.0
#
#                       Purchasing Power Parity 2019 (dollars)  \
# Country
# Syrian Arab Republic                                     0.0
#
#                          Country or region
# Country
# Syrian Arab Republic  Syrian Arab Republic

# %%
#check if duplicated values for Venezuela - duplicated => to be merged
working_df[working_df['Country or region'].str.contains("Venezuela")]
# Out:
#                Happiness Index 2019  GDP per capita  Social support  \
# Country
# Venezuela                     4.707            0.96           1.427
# Venezuela, RB                 0.000            0.00           0.000
#
#                Healthy life expectancy  Freedom to make life choices  \
# Country
# Venezuela                        0.805                         0.154
# Venezuela, RB                    0.000                         0.000
#
#                Generosity  Perceptions of corruption  \
# Country
# Venezuela           0.064                      0.047
# Venezuela, RB       0.000                      0.000
#
#                Gross National Income per Capita(dollars)  \
# Country
# Venezuela                                            0.0
# Venezuela, RB                                        0.0
#
#                Purchasing Power Parity 2019 (dollars) Country or region
# Country
# Venezuela                                         0.0         Venezuela
# ...

# %%
working_df['Country'] = working_df['Country or region'].replace(['Venezuela'],'Venezuela, RB')
working_df['Country or region'] = working_df['Country']

# %%
aggregation_functions = {'Happiness Index 2019': 'sum',
                         'GDP per capita': 'sum',
                         'Social support': 'sum',
                         'Healthy life expectancy': 'sum',
                         'Freedom to make life choices': 'sum',
                         'Generosity': 'sum',
                         'Perceptions of corruption': 'sum',
                         'Gross National Income per Capita(dollars)': 'sum', 
                         'Purchasing Power Parity 2019 (dollars)': 'sum', 
                         'Country or region': 'first'}
working_df = working_df.groupby(working_df['Country']).aggregate(aggregation_functions)

# %%
working_df[working_df['Country or region'].str.contains("Venezuela")]
# Out:
#                Happiness Index 2019  GDP per capita  Social support  \
# Country
# Venezuela, RB                 4.707            0.96           1.427
#
#                Healthy life expectancy  Freedom to make life choices  \
# Country
# Venezuela, RB                    0.805                         0.154
#
#                Generosity  Perceptions of corruption  \
# Country
# Venezuela, RB       0.064                      0.047
#
#                Gross National Income per Capita(dollars)  \
# Country
# Venezuela, RB                                        0.0
#
#                Purchasing Power Parity 2019 (dollars) Country or region
# Country
# Venezuela, RB                                     0.0     Venezuela, RB

# %%
#check if duplicated values for Russia - duplicated => to be merged
working_df[working_df['Country or region'].str.contains("Russia")]
# Out:
#                     Happiness Index 2019  GDP per capita  Social support  \
# Country
# Russia                             5.648           1.183           1.452
# Russian Federation                 0.000           0.000           0.000
#
#                     Healthy life expectancy  Freedom to make life choices  \
# Country
# Russia                                0.726                         0.334
# Russian Federation                    0.000                         0.000
#
#                     Generosity  Perceptions of corruption  \
# Country
# Russia                   0.082                      0.031
# Russian Federation       0.000                      0.000
#
#                     Gross National Income per Capita(dollars)  \
# Country
# Russia                                                    0.0
# Russian Federation                                    11260.0
#
#                     Purchasing Power Parity 2019 (dollars)   Country or region
# Country
# ...

# %%
working_df['Country'] = working_df['Country or region'].replace(['Russia'],'Russian Federation')
working_df['Country or region'] = working_df['Country']

# %%
aggregation_functions = {'Happiness Index 2019': 'sum',
                         'GDP per capita': 'sum',
                         'Social support': 'sum',
                         'Healthy life expectancy': 'sum',
                         'Freedom to make life choices': 'sum',
                         'Generosity': 'sum',
                         'Perceptions of corruption': 'sum',
                         'Gross National Income per Capita(dollars)': 'sum', 
                         'Purchasing Power Parity 2019 (dollars)': 'sum', 
                         'Country or region': 'first'}
working_df = working_df.groupby(working_df['Country']).aggregate(aggregation_functions)

# %%
working_df[working_df['Country or region'].str.contains("Russia")]
# Out:
#                     Happiness Index 2019  GDP per capita  Social support  \
# Country
# Russian Federation                 5.648           1.183           1.452
#
#                     Healthy life expectancy  Freedom to make life choices  \
# Country
# Russian Federation                    0.726                         0.334
#
#                     Generosity  Perceptions of corruption  \
# Country
# Russian Federation       0.082                      0.031
#
#                     Gross National Income per Capita(dollars)  \
# Country
# Russian Federation                                    11260.0
#
#                     Purchasing Power Parity 2019 (dollars)   Country or region
# Country
# Russian Federation                                 28270.0  Russian Federation

# %%
#check if duplicated values for Egypt - duplicated => to be merged
working_df[working_df['Country or region'].str.contains("Egypt")]
# Out:
#                   Happiness Index 2019  GDP per capita  Social support  \
# Country
# Egypt                            4.166           0.913           1.039
# Egypt, Arab Rep.                 0.000           0.000           0.000
#
#                   Healthy life expectancy  Freedom to make life choices  \
# Country
# Egypt                               0.644                         0.241
# Egypt, Arab Rep.                    0.000                         0.000
#
#                   Generosity  Perceptions of corruption  \
# Country
# Egypt                  0.076                      0.067
# Egypt, Arab Rep.       0.000                      0.000
#
#                   Gross National Income per Capita(dollars)  \
# Country
# Egypt                                                   0.0
# Egypt, Arab Rep.                                     2690.0
#
#                   Purchasing Power Parity 2019 (dollars) Country or region
# Country
# ...

# %%
working_df['Country'] = working_df['Country or region'].replace(['Egypt'],'Egypt, Arab Rep.')
working_df['Country or region'] = working_df['Country']

# %%
aggregation_functions = {'Happiness Index 2019': 'sum',
                         'GDP per capita': 'sum',
                         'Social support': 'sum',
                         'Healthy life expectancy': 'sum',
                         'Freedom to make life choices': 'sum',
                         'Generosity': 'sum',
                         'Perceptions of corruption': 'sum',
                         'Gross National Income per Capita(dollars)': 'sum', 
                         'Purchasing Power Parity 2019 (dollars)': 'sum', 
                         'Country or region': 'first'}
working_df = working_df.groupby(working_df['Country']).aggregate(aggregation_functions)

# %%
working_df[working_df['Country or region'].str.contains("Egypt")]
# Out:
#                   Happiness Index 2019  GDP per capita  Social support  \
# Country
# Egypt, Arab Rep.                 4.166           0.913           1.039
#
#                   Healthy life expectancy  Freedom to make life choices  \
# Country
# Egypt, Arab Rep.                    0.644                         0.241
#
#                   Generosity  Perceptions of corruption  \
# Country
# Egypt, Arab Rep.       0.076                      0.067
#
#                   Gross National Income per Capita(dollars)  \
# Country
# Egypt, Arab Rep.                                     2690.0
#
#                   Purchasing Power Parity 2019 (dollars) Country or region
# Country
# Egypt, Arab Rep.                                 11810.0  Egypt, Arab Rep.

# %%
#check if duplicated values for Trinidad and Tobago - duplicated => to be merged
working_df[working_df['Country or region'].str.contains("Trinidad")]
# Out:
#                      Happiness Index 2019  GDP per capita  Social support  \
# Country
# Trinidad & Tobago                   6.192           1.231           1.477
# Trinidad and Tobago                 0.000           0.000           0.000
#
#                      Healthy life expectancy  Freedom to make life choices  \
# Country
# Trinidad & Tobago                      0.713                         0.489
# Trinidad and Tobago                    0.000                         0.000
#
#                      Generosity  Perceptions of corruption  \
# Country
# Trinidad & Tobago         0.185                      0.016
# Trinidad and Tobago       0.000                      0.000
#
#                      Gross National Income per Capita(dollars)  \
# Country
# Trinidad & Tobago                                          0.0
# Trinidad and Tobago                                    16890.0
#
#                      Purchasing Power Parity 2019 (dollars)  \
# Country
# ...

# %%
working_df['Country'] = working_df['Country or region'].replace(['Trinidad & Tobago'],'Trinidad and Tobago')
working_df['Country or region'] = working_df['Country']

# %%
aggregation_functions = {'Happiness Index 2019': 'sum',
                         'GDP per capita': 'sum',
                         'Social support': 'sum',
                         'Healthy life expectancy': 'sum',
                         'Freedom to make life choices': 'sum',
                         'Generosity': 'sum',
                         'Perceptions of corruption': 'sum',
                         'Gross National Income per Capita(dollars)': 'sum', 
                         'Purchasing Power Parity 2019 (dollars)': 'sum', 
                         'Country or region': 'first'}
working_df = working_df.groupby(working_df['Country']).aggregate(aggregation_functions)

# %%
working_df[working_df['Country or region'].str.contains("Trinidad")]
# Out:
#                      Happiness Index 2019  GDP per capita  Social support  \
# Country
# Trinidad and Tobago                 6.192           1.231           1.477
#
#                      Healthy life expectancy  Freedom to make life choices  \
# Country
# Trinidad and Tobago                    0.713                         0.489
#
#                      Generosity  Perceptions of corruption  \
# Country
# Trinidad and Tobago       0.185                      0.016
#
#                      Gross National Income per Capita(dollars)  \
# Country
# Trinidad and Tobago                                    16890.0
#
#                      Purchasing Power Parity 2019 (dollars)  \
# Country
# Trinidad and Tobago                                 26950.0
#
#                        Country or region
# Country
# Trinidad and Tobago  Trinidad and Tobago

# %%
#check if duplicated values for Congo - duplicated => to be merged
working_df[working_df['Country or region'].str.contains("Congo")]
# Out:
#                      Happiness Index 2019  GDP per capita  Social support  \
# Country
# Congo (Brazzaville)                 4.812           0.673           0.799
# Congo (Kinshasa)                    4.418           0.094           1.125
# Congo, Dem. Rep.                    0.000           0.000           0.000
# Congo, Rep.                         0.000           0.000           0.000
#
#                      Healthy life expectancy  Freedom to make life choices  \
# Country
# Congo (Brazzaville)                    0.508                         0.372
# Congo (Kinshasa)                       0.357                         0.269
# Congo, Dem. Rep.                       0.000                         0.000
# Congo, Rep.                            0.000                         0.000
#
#                      Generosity  Perceptions of corruption  \
# Country
# Congo (Brazzaville)       0.105                      0.093
# Congo (Kinshasa)          0.212                      0.053
# ...

# %%
working_df['Country'] = working_df['Country or region'].replace(['Congo (Brazzaville)'],'Congo, Rep.')
working_df['Country or region'] = working_df['Country']

# %%
aggregation_functions = {'Happiness Index 2019': 'sum',
                         'GDP per capita': 'sum',
                         'Social support': 'sum',
                         'Healthy life expectancy': 'sum',
                         'Freedom to make life choices': 'sum',
                         'Generosity': 'sum',
                         'Perceptions of corruption': 'sum',
                         'Gross National Income per Capita(dollars)': 'sum', 
                         'Purchasing Power Parity 2019 (dollars)': 'sum', 
                         'Country or region': 'first'}
working_df = working_df.groupby(working_df['Country']).aggregate(aggregation_functions)

# %%
working_df['Country'] = working_df['Country or region'].replace(['Congo (Kinshasa)'],'Congo, Dem. Rep.')
working_df['Country or region'] = working_df['Country']

# %%
aggregation_functions = {'Happiness Index 2019': 'sum',
                         'GDP per capita': 'sum',
                         'Social support': 'sum',
                         'Healthy life expectancy': 'sum',
                         'Freedom to make life choices': 'sum',
                         'Generosity': 'sum',
                         'Perceptions of corruption': 'sum',
                         'Gross National Income per Capita(dollars)': 'sum', 
                         'Purchasing Power Parity 2019 (dollars)': 'sum', 
                         'Country or region': 'first'}
working_df = working_df.groupby(working_df['Country']).aggregate(aggregation_functions)

# %%
working_df[working_df['Country or region'].str.contains("Congo")]
# Out:
#                   Happiness Index 2019  GDP per capita  Social support  \
# Country
# Congo, Dem. Rep.                 4.418           0.094           1.125
# Congo, Rep.                      4.812           0.673           0.799
#
#                   Healthy life expectancy  Freedom to make life choices  \
# Country
# Congo, Dem. Rep.                    0.357                         0.269
# Congo, Rep.                         0.508                         0.372
#
#                   Generosity  Perceptions of corruption  \
# Country
# Congo, Dem. Rep.       0.212                      0.053
# Congo, Rep.            0.105                      0.093
#
#                   Gross National Income per Capita(dollars)  \
# Country
# Congo, Dem. Rep.                                      520.0
# Congo, Rep.                                          1750.0
#
#                   Purchasing Power Parity 2019 (dollars) Country or region
# Country
# ...

# %%
#check if duplicated values for Iran - duplicated => to be merged
working_df[working_df['Country or region'].str.contains("Iran")]
# Out:
#                     Happiness Index 2019  GDP per capita  Social support  \
# Country
# Iran                               4.548             1.1           0.842
# Iran, Islamic Rep.                 0.000             0.0           0.000
#
#                     Healthy life expectancy  Freedom to make life choices  \
# Country
# Iran                                  0.785                         0.305
# Iran, Islamic Rep.                    0.000                         0.000
#
#                     Generosity  Perceptions of corruption  \
# Country
# Iran                      0.27                      0.125
# Iran, Islamic Rep.        0.00                      0.000
#
#                     Gross National Income per Capita(dollars)  \
# Country
# Iran                                                      0.0
# Iran, Islamic Rep.                                     5420.0
#
#                     Purchasing Power Parity 2019 (dollars)   Country or region
# Country
# ...

# %%
working_df['Country'] = working_df['Country or region'].replace(['Iran'],'Iran, Islamic Rep.')
working_df['Country or region'] = working_df['Country']

# %%
aggregation_functions = {'Happiness Index 2019': 'sum',
                         'GDP per capita': 'sum',
                         'Social support': 'sum',
                         'Healthy life expectancy': 'sum',
                         'Freedom to make life choices': 'sum',
                         'Generosity': 'sum',
                         'Perceptions of corruption': 'sum',
                         'Gross National Income per Capita(dollars)': 'sum', 
                         'Purchasing Power Parity 2019 (dollars)': 'sum', 
                         'Country or region': 'first'}
working_df = working_df.groupby(working_df['Country']).aggregate(aggregation_functions)

# %%
working_df[working_df['Country or region'].str.contains("Iran")]
# Out:
#                     Happiness Index 2019  GDP per capita  Social support  \
# Country
# Iran, Islamic Rep.                 4.548             1.1           0.842
#
#                     Healthy life expectancy  Freedom to make life choices  \
# Country
# Iran, Islamic Rep.                    0.785                         0.305
#
#                     Generosity  Perceptions of corruption  \
# Country
# Iran, Islamic Rep.        0.27                      0.125
#
#                     Gross National Income per Capita(dollars)  \
# Country
# Iran, Islamic Rep.                                     5420.0
#
#                     Purchasing Power Parity 2019 (dollars)   Country or region
# Country
# Iran, Islamic Rep.                                 14560.0  Iran, Islamic Rep.

# %%
working_df['Country'] = working_df['Country or region'].replace(['Taiwan'],'Taiwan, China')
working_df['Country or region'] = working_df['Country']

# %%
aggregation_functions = {'Happiness Index 2019': 'sum',
                         'GDP per capita': 'sum',
                         'Social support': 'sum',
                         'Healthy life expectancy': 'sum',
                         'Freedom to make life choices': 'sum',
                         'Generosity': 'sum',
                         'Perceptions of corruption': 'sum',
                         'Gross National Income per Capita(dollars)': 'sum', 
                         'Purchasing Power Parity 2019 (dollars)': 'sum', 
                         'Country or region': 'first'}
working_df = working_df.groupby(working_df['Country']).aggregate(aggregation_functions)

# %%
working_df[working_df['Country or region'].str.contains("Taiwan")]
# Out:
#                Happiness Index 2019  GDP per capita  Social support  \
# Country
# Taiwan, China                 6.446           1.368            1.43
#
#                Healthy life expectancy  Freedom to make life choices  \
# Country
# Taiwan, China                    0.914                         0.351
#
#                Generosity  Perceptions of corruption  \
# Country
# Taiwan, China       0.242                      0.097
#
#                Gross National Income per Capita(dollars)  \
# Country
# Taiwan, China                                        0.0
#
#                Purchasing Power Parity 2019 (dollars) Country or region
# Country
# Taiwan, China                                     0.0     Taiwan, China

# %% [markdown]
# The data tyding and cleaning is almost at the finish line. I hope :)
# It was a big check for duplicated values, now it is time to remove the rows having only zero values since they do not bring any benefit for the analysis and data exploring.

# %%
working_df.shape
# Out:
# (226, 10)

# %%
# again selection of rows meeting the below conditions for having zero values in the below columns
select_remaining_zero_values = working_df[(working_df['Happiness Index 2019'] == 0) & 
                                    (working_df['Gross National Income per Capita(dollars)'] == 0) & 
                                   (working_df['Purchasing Power Parity 2019 (dollars)']==0) & (working_df["GDP per capita"] == 0) & 
                         (working_df["Social support"] == 0) & (working_df["Healthy life expectancy"] == 0)& 
                         (working_df["Freedom to make life choices"] == 0) & 
                        (working_df["Generosity"] == 0) & (working_df["Perceptions of corruption"] == 0)]
select_remaining_zero_values
# Out:
#                            Happiness Index 2019  GDP per capita  \
# Country
# American Samoa                              0.0             0.0
# Andorra                                     0.0             0.0
# Bermuda                                     0.0             0.0
# British Virgin Islands                      0.0             0.0
# Channel Islands                             0.0             0.0
# Cuba                                        0.0             0.0
# Eritrea                                     0.0             0.0
# Faroe Islands                               0.0             0.0
# French Polynesia                            0.0             0.0
# Gibraltar                                   0.0             0.0
# Greenland                                   0.0             0.0
# Guam                                        0.0             0.0
# Korea, Dem. People's Rep.                   0.0             0.0
# ...

# %%
# ... and again creating the list with the countries'names which fullfil the above conditions
remaining_zero_values_list = select_remaining_zero_values["Country or region"].tolist()
remaining_zero_values_list
# Out:
# ['American Samoa',
#  'Andorra',
#  'Bermuda',
#  'British Virgin Islands',
#  'Channel Islands',
#  'Cuba',
#  'Eritrea',
#  'Faroe Islands',
#  'French Polynesia',
#  'Gibraltar',
#  'Greenland',
#  'Guam',
#  "Korea, Dem. People's Rep.",
#  'Liechtenstein',
#  'Monaco',
#  'New Caledonia',
#  'Northern Mariana Islands',
#  'San Marino',
#  'St. Martin (French part)',
#  'Virgin Islands (U.S.)']

# %%
#deleting the zero value observations
index_names = working_df[(working_df['Happiness Index 2019'] == 0) & 
                                    (working_df['Gross National Income per Capita(dollars)'] == 0) & 
                                   (working_df['Purchasing Power Parity 2019 (dollars)']==0) & (working_df["GDP per capita"] == 0) & 
                         (working_df["Social support"] == 0) & (working_df["Healthy life expectancy"] == 0)& 
                         (working_df["Freedom to make life choices"] == 0) & 
                        (working_df["Generosity"] == 0) & (working_df["Perceptions of corruption"] == 0)].index
# index_names = df[ (df['Age'] >= 21) & (df['Age'] <= 23)].index 
# df.drop(index_names, inplace = True) 
working_df.drop(index_names, inplace=True)

# %%
working_df
# Out:
#                      Happiness Index 2019  GDP per capita  Social support  \
# Country
# Afghanistan                         3.203           0.350           0.517
# Albania                             4.719           0.947           0.848
# Algeria                             5.211           1.002           1.160
# Angola                              0.000           0.000           0.000
# Antigua and Barbuda                 0.000           0.000           0.000
# ...                                   ...             ...             ...
# Vietnam                             5.175           0.741           1.346
# West Bank and Gaza                  0.000           0.000           0.000
# Yemen, Rep.                         3.380           0.287           1.163
# Zambia                              4.107           0.578           1.058
# Zimbabwe                            3.663           0.366           1.114
#
# ...

# %%
working_df.shape
# Out:
# (206, 10)

# %%
#checking the dataset columns, since there were some bugs in the above formulas. Now seems that it is working :)
working_df.columns
# Out:
# Index(['Happiness Index 2019', 'GDP per capita', 'Social support',
#        'Healthy life expectancy', 'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption',
#        'Gross National Income per Capita(dollars)',
#        'Purchasing Power Parity 2019 (dollars)', 'Country or region'],
#       dtype='object')

# %%
working_df.dtypes
# Out:
# Happiness Index 2019                         float64
# GDP per capita                               float64
# Social support                               float64
# Healthy life expectancy                      float64
# Freedom to make life choices                 float64
# Generosity                                   float64
# Perceptions of corruption                    float64
# Gross National Income per Capita(dollars)    float64
# Purchasing Power Parity 2019 (dollars)       float64
# Country or region                             object
# dtype: object

# %%
country_classification_fin.dtypes
# Out:
# Country or region    object
# Region               object
# Income group         object
# dtype: object

# %%
# checking the column names of the final dataset having information about the income group of the countries (4 categories are available)
country_classification_fin.columns
# Out:
# Index(['Country or region', 'Region', 'Income group'], dtype='object')

# %%
# Merging the last dataset with the country classification data in order to add the Region and the Income group of the countries
final_df = pd.merge(working_df, country_classification_fin, how = 'outer', on = ['Country or region'])

# %%
final_df
# Out:
#      Happiness Index 2019  GDP per capita  Social support  \
# 0                   3.203           0.350           0.517
# 1                   4.719           0.947           0.848
# 2                   5.211           1.002           1.160
# 3                   0.000           0.000           0.000
# 4                   0.000           0.000           0.000
# ..                    ...             ...             ...
# 221                   NaN             NaN             NaN
# 222                   NaN             NaN             NaN
# 223                   NaN             NaN             NaN
# 224                   NaN             NaN             NaN
# 225                   NaN             NaN             NaN
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                      0.361                         0.000       0.158
# 1                      0.874                         0.383       0.178
# ...

# %%
# and again to replace the NaN with zeros
final_df = final_df.fillna(0)

# %%
final_df
# Out:
#      Happiness Index 2019  GDP per capita  Social support  \
# 0                   3.203           0.350           0.517
# 1                   4.719           0.947           0.848
# 2                   5.211           1.002           1.160
# 3                   0.000           0.000           0.000
# 4                   0.000           0.000           0.000
# ..                    ...             ...             ...
# 221                 0.000           0.000           0.000
# 222                 0.000           0.000           0.000
# 223                 0.000           0.000           0.000
# 224                 0.000           0.000           0.000
# 225                 0.000           0.000           0.000
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                      0.361                         0.000       0.158
# 1                      0.874                         0.383       0.178
# ...

# %%
#check if duplicated values for Korea - OK
final_df[final_df['Country or region'].str.contains("Korea")]
# Out:
#      Happiness Index 2019  GDP per capita  Social support  \
# 93                  5.895           1.301           1.219
# 218                 0.000           0.000           0.000
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 93                     1.036                         0.159       0.175
# 218                    0.000                         0.000       0.000
#
#      Perceptions of corruption  Gross National Income per Capita(dollars)  \
# 93                       0.056                                    33720.0
# 218                      0.000                                        0.0
#
#      Purchasing Power Parity 2019 (dollars)          Country or region  \
# 93                                  43430.0                Korea, Rep.
# 218                                     0.0  Korea, Dem. People's Rep.
#
#                   Region Income group
# 93   East Asia & Pacific  High income
# 218  East Asia & Pacific   Low income

# %%
#check if duplicated values for Russia - OK
final_df[final_df['Country or region'].str.contains("Taiwan")]
# Out:
#      Happiness Index 2019  GDP per capita  Social support  \
# 179                 6.446           1.368            1.43
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 179                    0.914                         0.351       0.242
#
#      Perceptions of corruption  Gross National Income per Capita(dollars)  \
# 179                      0.097                                        0.0
#
#      Purchasing Power Parity 2019 (dollars) Country or region  \
# 179                                     0.0     Taiwan, China
#
#                   Region Income group
# 179  East Asia & Pacific  High income

# %%
# checking if there are countries with no happiness index
to_be_deleted = final_df.loc[(final_df['Happiness Index 2019'] == 0) & (final_df['Income group'] != "")]
to_be_deleted
# Out:
#      Happiness Index 2019  GDP per capita  Social support  \
# 3                     0.0             0.0             0.0
# 4                     0.0             0.0             0.0
# 7                     0.0             0.0             0.0
# 11                    0.0             0.0             0.0
# 14                    0.0             0.0             0.0
# ..                    ...             ...             ...
# 221                   0.0             0.0             0.0
# 222                   0.0             0.0             0.0
# 223                   0.0             0.0             0.0
# 224                   0.0             0.0             0.0
# 225                   0.0             0.0             0.0
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 3                        0.0                           0.0         0.0
# 4                        0.0                           0.0         0.0
# ...

# %%
# checking the list with the countries names
list_for_deletion = to_be_deleted["Country or region"].values.tolist()
list_for_deletion
# Out:
# ['Angola',
#  'Antigua and Barbuda',
#  'Aruba',
#  'Bahamas, The',
#  'Barbados',
#  'Belize',
#  'Brunei Darussalam',
#  'Cabo Verde',
#  'Cayman Islands',
#  'Curaçao',
#  "Côte d'Ivoire",
#  'Djibouti',
#  'Dominica',
#  'Equatorial Guinea',
#  'Eswatini',
#  'Fiji',
#  'Gambia, The',
#  'Grenada',
#  'Guinea-Bissau',
#  'Guyana',
#  'Isle of Man',
#  'Kiribati',
#  'Kyrgyz Republic',
#  'Lao PDR',
#  'Macao SAR, China',
#  'Maldives',
#  'Marshall Islands',
#  'Micronesia, Fed. Sts.',
#  'Nauru',
#  'Oman',
#  'Palau',
#  'Papua New Guinea',
#  'Puerto Rico',
#  'Samoa',
#  'Seychelles',
#  'Sint Maarten (Dutch part)',
#  'Slovak Republic',
#  'Solomon Islands',
#  'St. Kitts and Nevis',
#  'St. Lucia',
#  'St. Vincent and the Grenadines',
#  'Sudan',
#  'Suriname',
#  'São Tomé and Principe',
#  'Timor-Leste',
#  'Tonga',
#  'Turks and Caicos Islands',
#  'Tuvalu',
#  'Vanuatu',
#  'West Bank and Gaza',
#  'American Samoa',
#  'Andorra',
#  'Bermuda',
# ...

# %%
#check if there are countries with empty Income group column
deletion_part_two = final_df.loc[(final_df['Income group'] == 0)]
deletion_part_two
# Out:
#      Happiness Index 2019  GDP per capita  Social support  \
# 62                  4.516           0.308           0.939
# 86                  4.944           0.569           0.808
# 97                  5.261           0.551           1.438
# 99                  4.796           0.764           1.030
# 134                 5.718           1.263           1.252
# 139                 4.696           0.657           1.247
# 161                 6.198           1.246           1.504
# 174                 4.212           0.811           1.149
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 62                     0.428                         0.382       0.269
# 86                     0.232                         0.352       0.154
# 97                     0.723                         0.508       0.300
# 99                     0.551                         0.547       0.266
# 134                    1.042                         0.417       0.191
# ...

# %%
# In order to see how many lines need to be deleted (simple checking how many rows need to be deleted on order to verify after if have deleted the proper number of rows...)
deletion_part_two.shape
# Out:
# (8, 12)

# %%
#removing the rows matching the below conditions for zero value in Happiness Index 2019 column and not empty Income grooup column
final_df.drop(final_df.loc[(final_df['Happiness Index 2019'] == 0) & (final_df['Income group'] != "")].index, inplace=True)

# %%
# deleting the rows having zero values in income group
final_df.drop(final_df.loc[(final_df['Income group'] == 0)].index, inplace=True)

# %%
final_df
# Out:
#      Happiness Index 2019  GDP per capita  Social support  \
# 0                   3.203           0.350           0.517
# 1                   4.719           0.947           0.848
# 2                   5.211           1.002           1.160
# 5                   6.086           1.092           1.432
# 6                   4.559           0.850           1.055
# ..                    ...             ...             ...
# 200                 4.707           0.960           1.427
# 201                 5.175           0.741           1.346
# 203                 3.380           0.287           1.163
# 204                 4.107           0.578           1.058
# 205                 3.663           0.366           1.114
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                      0.361                         0.000       0.158
# 1                      0.874                         0.383       0.178
# ...

# %% [markdown]
# And the dataframe final_df is ready to be analyzed. It has remaining 148 rows and 12 columns based on which I will try to figure out if Money can buy happiness and review what are the other factors impacting the happiness index. This will help to answer to the general question in subject.

# %% [markdown]
# <div style="text-align: left"><H3><font color=darkgreen>III Explore, Model and iNterprete</font></H3></div>
# <div style="text-align: justify">The data is ready to be used and explored. This is from where the fun part starts ...</div>
# <div style="text-align: justify">It is the part where “where the magic happens”!</div>

# %% [markdown]
# <div style="text-align: justify">Having our combined and final dataframe, it is tyme to start exploring the data and to search the main factors influencing the happiness index and especially if the money have very high impact.</div>

# %%
plt.scatter(final_df['Country or region'], final_df["Happiness Index 2019"], s=30)
plt.show()

# %% [markdown]
# <div style="text-align: justify"> The scatterplot chart looks "ugly"and almost nothing can be taken as conclusion out of it. The only reason I have left it in the project is because it represents the disrepancies in the happiness index worldwide. It cannot be identified if there is any trend or normal distribution of the happiness index value ...</div>

# %%
#creating bar chart for all the countries based on the Happiness Index value
final_df.plot(x ='Country or region', y='Happiness Index 2019', kind = 'bar',  colormap='Accent', figsize=(25,10))
plt.ylabel('Country Happiness Index 2019')
plt.title("Happiness Index 2019")
plt.show()

# %% [markdown]
# <div style="text-align: justify"> The upper barchart combines in one place the happiness index of all the countries in the dataset. The shrift is very small but even though we can identify which are the countries with high values and with are the not-happy countries. In order better to see the top 10 happiest and the top 10 not happy countries, I have prepared the below tables.</div>

# %%
#creating bar chart for all the countries based on the GDP per capita value
final_df.plot(x ='Country or region', y='GDP per capita', kind = 'bar',  colormap='viridis', figsize=(25,10))
plt.ylabel('Country GDP per capita')
plt.title("GDP per capita")
plt.show()

# %% [markdown]
# <div style="text-align: justify"> The above bar chart is also a bit too crowded with many data but at the same time can be easily seen that here we have significant deviations among the countries.</div>

# %%
#creating bar chart for all the countries based on the Social support indicator value
final_df.plot(x ='Country or region', y='Social support', kind = 'bar',  colormap='magma', figsize=(25,10))
plt.ylabel('Social support')
plt.title("Social support")
plt.show()

# %% [markdown]
# <div style="text-align: justify"> We have also some values which are too high or low and at the same time the deviations are not that huge. The difference in the high values is not so big. Even though we have a country with zero value (Central African Republic).</div>

# %%
#creating bar chart for all the countries based on the Healthy life expectancy indicator value
final_df.plot(x ='Country or region', y='Healthy life expectancy', kind = 'bar',  colormap='inferno', figsize=(25,10))
plt.ylabel('Healthy life expectancy')
plt.title("Healthy life expectancy")
plt.show()

# %% [markdown]
# <div style="text-align: justify"> From the chart we see that the responses (values) in the Healthy life expectancy are varaing a lot. Mainly in the countries in Africa (Somaliya, Sierra Leone, Central African Republic, South Sudan etc.) we see very low values compared to the outher countreis. The highest value in therms of healthy life expectancy is in Singapore. </div>

# %%
#creating bar chart for all the countries based on the Freedom to make life choices indicator value
final_df.plot(x ='Country or region', y='Freedom to make life choices', kind = 'bar',  colormap='summer', figsize=(25,10))
plt.ylabel('Freedom to make life choices')
plt.title("Freedom to make life choices")
plt.show()

# %% [markdown]
# <div style="text-align: justify"> The chart with the Freedom to make life choices again shows many deviations and different values. The lowest freedom we can see in Haiti, South Sudan, Syria as outliners. The highest value is in Uzbekistan. </div>

# %%
#creating bar chart for all the countries based on the Generosity indicator value
final_df.plot(x ='Country or region', y='Generosity', kind = 'bar',  colormap='winter', figsize=(25,10))
plt.ylabel('Generosity')
plt.title("Generosity")
plt.show()

# %% [markdown]
# <div style="text-align: justify"> Many, many different values. The lowest value is with Greece and Botzwana. And one outliner with significant hiher value than the rest Myanmar. </div>

# %%
#creating bar chart for all the countries based on the Perceptions of corruption indicator value
final_df.plot(x ='Country or region', y='Perceptions of corruption', kind = 'bar',  colormap='hot', figsize=(25,10))
plt.ylabel('Perceptions of corruption')
plt.title("Perceptions of corruption")
plt.show()

# %% [markdown]
# <div style="text-align: justify"> I thought that the upper bar charts have big differences in the value but it seems that in terms of the perception of corrupption the values vary the most (up till now). Seems that the different coountries have significant difference in the perception of corruption ...</div>

# %%
#creating bar chart for all the countries based on the Gross National Income per Capita(dollars) indicator value
final_df.plot(x ='Country or region', y='Gross National Income per Capita(dollars)', kind = 'bar',  colormap='autumn', figsize=(25,10))
plt.ylabel('Gross National Income per Capita(dollars)')
plt.title("Gross National Income per Capita(dollars)")
plt.show()

# %% [markdown]
# <div style="text-align: justify"> Very interesting outcome. The majority of the countries seems to be in the middle range of the GNIPC. The leader with the biggest income is Switzerland (but this is not the country on the first place based on the happiness index. Followed by Norway, Luxemburg etc. The chart is quite different than the chart containign the information about the GBP per capita. The reason could be because of the different sources and approchhes for the calculation. </div>

# %%
#creating bar chart for all the countries based on the Purchasing Power Parity 2019 (dollars) indicator value
final_df.plot(x ='Country or region', y='Purchasing Power Parity 2019 (dollars)', kind = 'bar',  colormap='hsv', figsize=(25,10))
plt.ylabel('Purchasing Power Parity 2019 (dollars)')
plt.title("Purchasing Power Parity 2019 (dollars)")
plt.show()

# %% [markdown]
# <div style="text-align: justify"> It is not surprizing that the chart is similar to the one with the data for GNIPC. There are some discrepancies though - based on the purchase power parity the leader is Quatar, followed by Singapore. Switzerland and Luxemburg are also in the top 10. </div>

# %% [markdown]
# <div style="text-align: justify"> In relation with the above charts let's see which are the top happiest and the least happiest countries.</div>
# <div style="text-align: justify"> The country leading among the rest is Demark and at the bottom line is South Sudan.</div>

# %%
top_ten_happiest = final_df.nlargest(10,['Happiness Index 2019'])
top_ten_happiest
# Out:
#      Happiness Index 2019  GDP per capita  Social support  \
# 59                  7.769           1.340           1.587
# 47                  7.600           1.383           1.573
# 135                 7.554           1.488           1.582
# 77                  7.494           1.380           1.624
# 128                 7.488           1.396           1.522
# 176                 7.480           1.452           1.526
# 175                 7.343           1.387           1.487
# 129                 7.307           1.303           1.557
# 31                  7.278           1.365           1.505
# 9                   7.246           1.376           1.475
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 59                     0.986                         0.596       0.153
# 47                     0.996                         0.592       0.252
# 135                    1.028                         0.603       0.271
# ...

# %%
top_ten_not_happy = final_df.nsmallest(10,['Happiness Index 2019'])
top_ten_not_happy
# Out:
#      Happiness Index 2019  GDP per capita  Social support  \
# 166                 2.853           0.306           0.575
# 33                  3.083           0.026           0.000
# 0                   3.203           0.350           0.517
# 181                 3.231           0.476           0.885
# 151                 3.334           0.359           0.711
# 203                 3.380           0.287           1.163
# 109                 3.410           0.191           0.560
# 177                 3.462           0.619           0.378
# 22                  3.488           1.041           1.145
# 73                  3.597           0.323           0.688
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 166                    0.295                         0.010       0.202
# 33                     0.105                         0.225       0.235
# 0                      0.361                         0.000       0.158
# ...

# %% [markdown]
# <div style="text-align: justify">From the above tables it appeared that in the columns Gross National Income per Capita(dollars) and Purchasing Power Parity 2019 (dollars) there are still some countries for which there is no data, thus their values were relpaced with zeros. They do have Happiness index calculated with the different survey, they do have values for the category related to the Income but do not have GNI value.</div>
# <div style="text-align: justify"> Having in mind that the only missing data is in those two columns I will try to explore if there would be significant impact if we drop/ remove those observations and will perform part of the analysis with and without them, since keeping them in the dataset might affect the correlation. </div>

# %%
# Taking the zero values countries based on columns Gross National Income per Capita(dollars) and Purchasing Power Parity 2019 (dollars)
missed_zero_values_in_GNI_columns = final_df.loc[(final_df['Gross National Income per Capita(dollars)'] == 0) & (final_df['Purchasing Power Parity 2019 (dollars)'] == 0)]
missed_zero_values_in_GNI_columns
# Out:
#      Happiness Index 2019  GDP per capita  Social support  \
# 164                 4.668           0.000           0.698
# 166                 2.853           0.306           0.575
# 177                 3.462           0.619           0.378
# 179                 6.446           1.368           1.430
# 200                 4.707           0.960           1.427
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 164                    0.268                         0.559       0.243
# 166                    0.295                         0.010       0.202
# 177                    0.440                         0.013       0.331
# 179                    0.914                         0.351       0.242
# 200                    0.805                         0.154       0.064
#
#      Perceptions of corruption  Gross National Income per Capita(dollars)  \
# 164                      0.270                                        0.0
# ...

# %%
#Checking how many are those records
missed_zero_values_in_GNI_columns.shape
# Out:
# (5, 12)

# %% [markdown]
# <div style="text-align: justify">The good in the outcome is that we have only 5 observations matching the condition above. Probably the impact should not be significant. Let's check it!</div>

# %%
# Creating a copy of the final dataset prior removing the remaining zeros in order to be able to compare the 2 datasets in the analysis
final_df_no_zeros = final_df.copy()
final_df_no_zeros
# Out:
#      Happiness Index 2019  GDP per capita  Social support  \
# 0                   3.203           0.350           0.517
# 1                   4.719           0.947           0.848
# 2                   5.211           1.002           1.160
# 5                   6.086           1.092           1.432
# 6                   4.559           0.850           1.055
# ..                    ...             ...             ...
# 200                 4.707           0.960           1.427
# 201                 5.175           0.741           1.346
# 203                 3.380           0.287           1.163
# 204                 4.107           0.578           1.058
# 205                 3.663           0.366           1.114
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                      0.361                         0.000       0.158
# 1                      0.874                         0.383       0.178
# ...

# %%
# Removing the last remaining zero values
final_df_no_zeros.drop(final_df_no_zeros.loc[(final_df_no_zeros['Gross National Income per Capita(dollars)'] == 0) & (final_df_no_zeros['Purchasing Power Parity 2019 (dollars)'] == 0)].index, inplace=True)

# %%
final_df_no_zeros
# Out:
#      Happiness Index 2019  GDP per capita  Social support  \
# 0                   3.203           0.350           0.517
# 1                   4.719           0.947           0.848
# 2                   5.211           1.002           1.160
# 5                   6.086           1.092           1.432
# 6                   4.559           0.850           1.055
# ..                    ...             ...             ...
# 198                 6.174           0.745           1.529
# 201                 5.175           0.741           1.346
# 203                 3.380           0.287           1.163
# 204                 4.107           0.578           1.058
# 205                 3.663           0.366           1.114
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                      0.361                         0.000       0.158
# 1                      0.874                         0.383       0.178
# ...

# %%
# Histograms for all the examined factors in the datased (including the zero values in Gross National Income per Capita(dollars) and Purchasing Power Parity 2019 (dollars) )
final_df.hist()
plt.rcParams["figure.figsize"] = [25,15]
plt.show()

# %% [markdown]
# <div style="text-align: justify"> On the above histograms we see that (as I mentioned above) there is not factor with normal distribution. And at the same time we have 4 with exponencial distribution</div>
# <div style="text-align: justify"> All histograms are asymmetric. </div>

# %%
# Histograms for all the examined factors in the datased (exculuding the zero values in Gross National Income per Capita(dollars) and Purchasing Power Parity 2019 (dollars) )
final_df_no_zeros.hist()
plt.rcParams["figure.figsize"] = [25,15]
plt.show()

# %% [markdown]
# <div style="text-align: justify"> Histograms for all the examined factors in the datased (exculuding the zero values in Gross National Income per Capita(dollars) and Purchasing Power Parity 2019 (dollars) are also asymmetric. </div>
# <div style="text-align: justify"> Also, we do not have normal distribution of the values of the different factors. And we have still 4 exponential distributions.</div>
# <div style="text-align: justify"> It seems that there is not such a big difference if we would use the data with the remainig zero values in the GNI & PPP columns. </div>

# %% [markdown]
# <div style="text-align: justify"> Based on the outcome from the histograms and due to the fact that we do not have normal distribution of the data, the linear (Pearson) correlation would not be exactly the appropriate correlation method for the analysis. Even though, I will try to test it both with Pearson and Spearman correlations.</div>

# %% [markdown]
# <div style="text-align: justify">We continue further with reviewing the date and exploring the values using some simple pivot tables based on the available Income categories and regions. Also will create couple of charts for better visualization of the data. </div>

# %% [markdown]
# <div style="text-align: justify">1. The first table and chart represents the grouping of the countries under review based on the category variable for their average income.</div>
# <div style="text-align: justify">2. The second table and chart represents the grouping of the countries based on the category variable for their mean value of the income based on the dataset from which we have removed the final observations having zero value in GNIPC and PPP.</div>
# <div style="text-align: justify">3. The second table and chart represents the grouping of the countries based on the category variable for their mean value of the income.</div>
# <div style="text-align: justify">4. As an outcome:</div>
# <div style="text-align: justify">    - there is no difference between the average and mean value of the countries happines index and  </div>
# <div style="text-align: justify">    - there is insignificant difference in the average values if we would use the dataset with or without the 5 observations with zero values in GNIPC and PPP.</div>

# %%
#create pivot table with the count of the countries following under certain the income group category
pivoted_df_income_gr_count_of_countries = pd.pivot_table(final_df,index=['Income group'], values=['Country or region'],aggfunc="count")
pivoted_df_income_gr_count_of_countries
# Out:
#                      Country or region
# Income group
# High income                         49
# Low income                          24
# Lower middle income                 35
# Upper middle income                 40

# %%
#create pivot table with the average happiness index based on the income group category
pivoted_df_income_gr_count_of_countries_no_zeros = pd.pivot_table(final_df_no_zeros,index=['Income group'], values=['Happiness Index 2019'],aggfunc=np.average)
pivoted_df_income_gr_count_of_countries_no_zeros
# Out:
#                      Happiness Index 2019
# Income group
# High income                      6.554396
# Low income                       4.069714
# Lower middle income              4.862000
# Upper middle income              5.404744

# %%
pivoted_df_income_gr_count_of_countries_mean = pd.pivot_table(final_df,index=['Income group'], values=['Happiness Index 2019'],aggfunc='mean')
pivoted_df_income_gr_count_of_countries_mean
# Out:
#                      Happiness Index 2019
# Income group
# High income                      6.552184
# Low income                       4.018625
# Lower middle income              4.862000
# Upper middle income              5.387300

# %%
#creating 2 bar charts based on the above 2 pivot tables. It seems that there is no difference between the mean and average values
barchart_income_gr_count_of_countries = pivoted_df_income_gr_count_of_countries.plot(kind='bar',color="y")
barchart_income_gr_count_of_countries_no_zeros = pivoted_df_income_gr_count_of_countries_no_zeros.plot(kind='bar',color="g")

# %% [markdown]
# <div style="text-align: justify"> Now, out of curiosity, let's see what is the status if we explore the average happiness index based on the region of the countries.</div>
# <div style="text-align: justify"> Respectively we have also the bar chart, from where we can see that the happiest people are situated in North America followed by Europe and Central Asia. The unhappy countries are situated in Sub-Saharan Africa. </div>
# <div style="text-align: justify">Also, if we expand a bit the pivot, adding the Income group to the Region, we will see the distribution based on the specific income category</div>

# %%
#create pivot table
pivoted_df_region_avg_happiness = pd.pivot_table(final_df,index=['Region'], values=['Happiness Index 2019'],aggfunc=np.average)
pivoted_df_region_avg_happiness
# Out:
#                             Happiness Index 2019
# Region
# East Asia & Pacific                     5.708438
# Europe & Central Asia                   6.094468
# Latin America & Caribbean               5.954429
# Middle East & North Africa              5.342222
# North America                           7.085000
# South Asia                              4.526857
# Sub-Saharan Africa                      4.279189

# %% [markdown]
# <div style="text-align: justify"> And the visualization with the line chart ... </div>

# %%
#create line chart based on the above pivot table
linechart_df_region_avg_happiness = pivoted_df_region_avg_happiness.plot(kind='line',color="b")

# %%
# updated pivot table - additing the income group to the above pivot with region and average happiness index
pivoted_df_region_income_avg_happiness = pd.pivot_table(final_df,index=['Region', 'Income group'], values=['Happiness Index 2019'],aggfunc=np.average)
pivoted_df_region_income_avg_happiness
# Out:
#                                                 Happiness Index 2019
# Region                     Income group
# East Asia & Pacific        High income                      6.350571
#                            Lower middle income              5.030200
#                            Upper middle income              5.432500
# Europe & Central Asia      High income                      6.629857
#                            Low income                       5.467000
#                            Lower middle income              5.345000
#                            Upper middle income              5.286800
# Latin America & Caribbean  High income                      6.312500
#                            Low income                       3.597000
#                            Lower middle income              5.999250
#                            Upper middle income              6.016583
# Middle East & North Africa High income                      6.522714
# ...

# %% [markdown]
# <div style="text-align: justify">From the pivot table above (and better from the bar graphic below) we can see that the better income group, the higher is the average happiness index. And this dependancy sems to be valid for all the regions. Everywhere the countries with high Income has higher average happiness index. This should mean something in possitive term for proving that the money can "buy" happines.</div>
# <div style="text-align: justify"> In orther to prove this, we continue exploring the data. We need also to explore which of the other factors have high influence on people in order to feel happy ...</div>

# %%
#create grouped bar chart based ont the original data (final_df), grouped by region and then the income categoty, showing the happiness index
# use Seaborn styles
sns.set()
region_income_bar = pd.pivot_table(final_df, index= 'Region', columns= 'Income group', values= "Happiness Index 2019").plot(kind= 'bar')
region_income_bar.plot(figsize=(25,15))
plt.ylabel("Happiness Index")
# Out:
# Text(0, 0.5, 'Happiness Index')

# %% [markdown]
# <div style="text-align: justify"> In the following pivot tables I will calculate the mean and average values of all the factors and for all the countries in the dataset. With this we will able to see if there is any direct link between the different factors and the happiness. </div>

# %%
# Create pivot table and calculation of the mean values of all the factors in the score of the analysis
pivoted_df_income_gr_mean_values = pd.pivot_table(final_df,index=["Income group"], values=['Happiness Index 2019', 'GDP per capita', 'Social support',
       'Healthy life expectancy', 'Freedom to make life choices', 'Generosity',
       'Perceptions of corruption',
       'Gross National Income per Capita(dollars)',
       'Purchasing Power Parity 2019 (dollars)'],aggfunc=np.mean)
pivoted_df_income_gr_mean_values
# Out:
#                      Freedom to make life choices  GDP per capita  Generosity  \
# Income group
# High income                              0.462612        1.329469    0.194224
# Low income                               0.273833        0.268333    0.215042
# Lower middle income                      0.386086        0.668914    0.200171
# Upper middle income                      0.385250        1.000950    0.141850
#
#                      Gross National Income per Capita(dollars)  \
# Income group
# High income                                       37987.346939
# Low income                                          587.500000
# Lower middle income                                2319.142857
# Upper middle income                                6945.500000
#
#                      Happiness Index 2019  Healthy life expectancy  \
# Income group
# High income                      6.552184                 0.955347
# Low income                       4.018625                 0.399208
# ...

# %%
# Create pivot table and calculation of the average values of all the factors in the score of the analysis
pivoted_data_income_group_avg_values = pd.pivot_table(final_df,index=["Income group"], values=['Happiness Index 2019', 'GDP per capita', 'Social support',
       'Healthy life expectancy', 'Freedom to make life choices', 'Generosity',
       'Perceptions of corruption',
       'Gross National Income per Capita(dollars)',
       'Purchasing Power Parity 2019 (dollars)'],aggfunc=np.average)
pivoted_data_income_group_avg_values
# Out:
#                      Freedom to make life choices  GDP per capita  Generosity  \
# Income group
# High income                              0.462612        1.329469    0.194224
# Low income                               0.273833        0.268333    0.215042
# Lower middle income                      0.386086        0.668914    0.200171
# Upper middle income                      0.385250        1.000950    0.141850
#
#                      Gross National Income per Capita(dollars)  \
# Income group
# High income                                       37987.346939
# Low income                                          587.500000
# Lower middle income                                2319.142857
# Upper middle income                                6945.500000
#
#                      Happiness Index 2019  Healthy life expectancy  \
# Income group
# High income                      6.552184                 0.955347
# Low income                       4.018625                 0.399208
# ...

# %% [markdown]
# <div style="text-align: justify"> Here based on the mean values of the factors splited per the category of the Income Group, we notice that:</div>
# <div style="text-align: justify">  * The countries which are categorized in the "High income" group has the highest mean values of all factors. We exclude the GNIPC and the PPP of course, since they usually they should be the base for categorization (despite the fact that the values are taken from different datasets).</div>
# <div style="text-align: justify">  ** Respectively, the countries which are in the "Low income" category has the lowest mean values of all factors.</div
# <div style="text-align: justify">  *** From first sight, from this pivot table I can conclude that indead the money has significant influence over the happiness index (at least based ont he mean values).</div>
# <div style="text-align: justify"> Also, as we mentioned above in the project, here the mean and average has the same values. </div>

# %% [markdown]
# <div style="text-align: justify"> We do continue further with the analysis in order to find out a solid answer on the general question. </div>

# %%
# Creating pivot table in order to see how many countries follows under the specific income categories
pivoted_df_income_gr_count_of_countries = pd.pivot_table(final_df,index=["Income group"], values=['Country or region'],aggfunc="count")
pivoted_df_income_gr_count_of_countries
# Out:
#                      Country or region
# Income group
# High income                         49
# Low income                          24
# Lower middle income                 35
# Upper middle income                 40

# %% [markdown]
# <div style="text-align: justify"> In the following table we will compute the correlation for all factors baed on the pivoted average data. Statistically (and most probably) this would not be the best approach but I am curious to see the result.</div>

# %%
#calculating correlation and visualizing it in a table
corr_data_avg_values = pd.DataFrame(pivoted_data_income_group_avg_values)
corr_data_avg_values.corr()
# Out:
#                                            Freedom to make life choices  \
# Freedom to make life choices                                   1.000000
# GDP per capita                                                 0.949944
# Generosity                                                    -0.340021
# Gross National Income per Capita(dollars)                      0.799341
# Happiness Index 2019                                           0.954953
# Healthy life expectancy                                        0.955503
# Perceptions of corruption                                      0.462715
# Purchasing Power Parity 2019 (dollars)                         0.855259
# Social support                                                 0.963861
#
#                                            GDP per capita  Generosity  \
# Freedom to make life choices                     0.949944   -0.340021
# GDP per capita                                   1.000000   -0.504919
# ...

# %% [markdown]
# <div style="text-align: justify"> The table showing the correlation between all the factors in scope is a bit complicated to read because of the many columns/rows. In order to make it easier to read I will create heatmaps - one based on the final dataframe and on the pivoted mean values data. </div>

# %% [markdown]
# <div style="text-align: justify">As a continuation, I have decided to explore how much correlated are the selected indicators with the happiness score,
# so we will plot this information in a correlation heatmap.</div>

# %%
# Creation of heatmap based on the working and tidy dataset - final_df
def correlation_matrix(final_df):
    corr_df = pd.DataFrame(data=final_df)
    plt.figure()
    sns.heatmap(corr_df.corr(method="pearson"), center=0, annot=True, vmin=-1, vmax=1, cmap="RdBu_r")
    plt.savefig("correlations.png")

# %%
correlation_matrix(final_df)

# %% [markdown]
# <div style="text-align: justify">This plot is showing some very clear conclusions. The first noticeable fact is that the GDP per capita is highly correlated with the happiness score of the countries. There is also a strong correlation between the GNI per capita (GNIPC) and the Purchasing Power Parity (PPP) and the happiness index of the countries. The Healthy Life Expectancy and the Social support which are also strongly correlated with the happiness index has a bit higher correlation than the GNIPC and the PPP. Knowing these facts, it's reasonable to confirm that the social security level and the healthy life expectancy of a population are directly related with its wealth (strong correlation with GBP and moderate with GNI & PPP).</div>
# <div style="text-align: justify">Furthermore, based on the high correlation between the the GDP per capita indicator, GNI per capita indicator and PPP and the level of happiness, so we can also confirm that the richness of a country is strongly conditioning the happiness of the population.</div>
# <div style="text-align: justify"> On the other hand, as per the heatmap results, we can make an intersting persumption that the Freedom to make choices has moderate corelation with the happiness of the examined counties, with even lower correlation is the Preception of corruption.</div>
# <div style="text-align: justify"> Also, based on the above heatmap, we can conclude that the Generocity has no impact on the happiness of the counties' population, actually the correlation is negligible.</div>

# %% [markdown]
# <div style="text-align: justify">Now to explore also te correlation based on the mean values of the facttors taken from the privoted data.</div>

# %%
#Heatmap based on mean values get from the pivoted data - pivoted_df_income_gr_mean_values
def correlation_matrix(pivoted_df_income_gr_mean_values):
    plt.figure()
    sns.heatmap(pivoted_df_income_gr_mean_values.corr(), center=0, annot=True, vmin=-1, vmax=1, cmap="RdBu_r")
    plt.savefig("correlations.png")
correlation_matrix(pivoted_df_income_gr_mean_values)

# %% [markdown]
# <div style="text-align: justify"> From the second heatmap, we can notice that the correlation of the happiness index with the GBP, GNI, PPP, Freedom to make chices, Healthy life expectancy andsocial support is even stronger. Based on the correlation coefficient from this heatmap we cannot concude straightforward if the money are the only one factor that make people happier (for sure they have big influence).</div>
# <div style="text-align: justify"> Based on this heatmap is also very visible the negative correlation between the happiness of the population and Generocity levels. In fact, the Generocity is negatively correlated with almost all of the factors in scope. And as it seems the wealthier is a population (GDP) the less generous it is. </div>
# <div style="text-align: justify"> In my view, we can assume that all of the factors (except Generocity and Perception of corruption) are strongly correlated between themselves.</div>
# <div style="text-align: justify"> This makes me assume, that the countries' population consider that with money (GDP, GNI, PPP) people can buy everything... (a bit naive assumption, not with statistical prove since this is not always the main case). </div>

# %%
final_df.columns
# Out:
# Index(['Happiness Index 2019', 'GDP per capita', 'Social support',
#        'Healthy life expectancy', 'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption',
#        'Gross National Income per Capita(dollars)',
#        'Purchasing Power Parity 2019 (dollars)', 'Country or region', 'Region',
#        'Income group'],
#       dtype='object')

# %%
#let's rename the columns of the dataset in order to be able to calculate the Spearman correlation
renamed_final_df=final_df.rename(columns = {'Happiness Index 2019':'Happiness_Index', 'GDP per capita':'GDP_PC','Social support':'Social_support',
                                            'ealthy life expectancy':'Life_expectancy','Freedom to make life choices':'Freedom_of_choice','Perceptions of corruption':'Corruption',
                                           'Gross National Income per Capita(dollars)':'GNIPC','Purchasing Power Parity 2019 (dollars)':'PPP', 
                                            'Country or region':'Country', 'Region':'Region', 'Income group':'Income_group'})
renamed_final_df.head()
# Out:
#    Happiness_Index  GDP_PC  Social_support  Healthy life expectancy  \
# 0            3.203   0.350           0.517                    0.361
# 1            4.719   0.947           0.848                    0.874
# 2            5.211   1.002           1.160                    0.785
# 5            6.086   1.092           1.432                    0.881
# 6            4.559   0.850           1.055                    0.815
#
#    Freedom_of_choice  Generosity  Corruption    GNIPC      PPP      Country  \
# 0              0.000       0.158       0.025    540.0   2330.0  Afghanistan
# 1              0.383       0.178       0.027   5240.0  14350.0      Albania
# 2              0.086       0.073       0.114   3970.0  11530.0      Algeria
# 5              0.471       0.066       0.050  11200.0  22060.0    Argentina
# 6              0.283       0.095       0.064   4680.0  14460.0      Armenia
#
#                        Region         Income_group
# ...

# %%
# calculation of Spearman correlation
corr_df = pd.DataFrame(data=final_df)

# %%
# calculation of Spearman correlation - table format
corrrelation = corr_df.corr(method="spearman")
corrrelation
# Out:
#                                            Happiness Index 2019  \
# Happiness Index 2019                                   1.000000
# GDP per capita                                         0.813421
# Social support                                         0.819203
# Healthy life expectancy                                0.807539
# Freedom to make life choices                           0.567888
# Generosity                                             0.080430
# Perceptions of corruption                              0.252445
# Gross National Income per Capita(dollars)              0.823263
# Purchasing Power Parity 2019 (dollars)                 0.802589
#
#                                            GDP per capita  Social support  \
# Happiness Index 2019                             0.813421        0.819203
# GDP per capita                                   1.000000        0.772959
# Social support                                   0.772959        1.000000
# ...

# %%
#create heatmap with Spearman correlation
def correlation_matrix_spearman(final_df):
    corr_df = pd.DataFrame(data=final_df)
    plt.figure()
    sns.heatmap(corr_df.corr(method="spearman"), center=0, annot=True, vmin=-1, vmax=1, cmap="YlOrRd")
    plt.savefig("correlations.png")

# %%
correlation_matrix_spearman(final_df)

# %% [markdown]
# <div style="text-align: justify">Pearson correlation assumes that the data we are comparing is normally distributed. When that assumption is not true, the correlation value is reflecting the true association. Spearman correlation does not assume that data is from a specific distribution, so it is a non-parametric correlation measure. Spearman correlation is also known as Spearman’s rank correlation as it computes correlation coefficient on rank values of the data.</div>

# %% [markdown]
# <div style="text-align: justify">As stated above in the project chapter, there is no normal distribution between the values of the observations. Thus we will compare the result of the Pearson & Spearman correlation</div>
# <div style="text-align: justify">The new red-orange-yellow heatmap shows the Spearman correlation coefficient.</div>
# <div style="text-align: justify">The result is that we have stronger correlation based on the higher correlation coefficients.</div>
# <div style="text-align: justify">The stongest correlation with the Happiness index has GNIPC and the Social support (coef.0.82). Also, with strong correlation with the happiness we have GDP and the Healthy life expectancy (coef.0.81), followed by PPP (0.80). Freedom to make choices seems having moderate correlation with the happiness.
# The correlation between the happiness index and the generocity and perception of corruption is negligable.</div>
# <div style="text-align: justify">Here we can notice also that there is very strong correlation between the healthy life expectancy and the GDP, GNI and PPP, and strong correlation with the social support. </div>
# <div style="text-align: justify">The social support on the other side has strong correlation with the GDP, GNI and PPP. </div>

# %% [markdown]
# <div style="text-align: left"><H3><font color=darkgreen>Conclusion</font></H3></div>
#
# <div style="text-align: justify">Having the available data reveiewed and examined, we can make the following conclusions: </div>
# <div style="text-align: justify">1) The majority of countries with higher happiness index also have also greater wealth (GDP, GNI, PPP). <br>
# <div style="text-align: justify">2) The majority of countries with higher healthy life expectancy have also great wealth. <br>
# 3) Citizens of countries with better economic development (GDP, GNI, PPP) also have great chanse to live since they have better social support. <br>
# 4) The better social support is available for the population, the happier are the people living in this country. <br>
# 5) Valid for majority of the countries is that the generocity has no influence on the happiness of the people, which makes me think that it is not needed being good to each-other in order to feel happy. <br>
# 6) The perception of corruption also has almost no influence on the happiness of the population. This is a bit strange as an outcome of the analysis. <br>
# 7) Having higher freedom to make choices not always leads to increasing the happiness. Probably it depends on what type of choices you need to take... If I consider myself, sometimes, I do prefer not having a choice (in some rare cases). <br>
# 8) Finally, it seems that the answer of the question is positive after all - the money can "buy" happiness. If not directly, it can be done indirectly - through the services like social security, better access to health care and better medicines, doctors, support (whatever needed). <br>
# As a woman, I always feel happy when I have the chance to buy something (I need to have higher income to do that). And it is alsu true that the money cannot "buy" everything...</div>
